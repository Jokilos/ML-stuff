# %% [markdown]
# # PPO and RND for MiniHack: Introduction

# %%
### BEGIN SOLUTION - Student's name
# Jakub Nowacki 
### END SOLUTION

### BEGIN SOLUTION - Message
# ALL_DONE - I have completed every task, and my solutions work correctly
### END SOLUTION

# %% [markdown]
# In this homework, we will explore [<b>Proximal Policy Optimization (PPO)</b>](https://arxiv.org/abs/1707.06347) combined with [<b>Random Network Distillation (RND)</b>](https://arxiv.org/abs/1810.12894) in the context of [MiniHack](https://github.com/facebookresearch/minihack) environments. These environments are challenging procedurally-generated tasks based on the [NetHack Learning Environment (NLE)](https://github.com/heiner/nle), designed to test advanced reinforcement learning algorithms. While PPO is a robust and popular policy optimization algorithm, RND introduces intrinsic rewards to encourage exploration in sparse-reward environments.
#
# The combination of PPO and RND addresses two key challenges in reinforcement learning:
# - <b>Sparse Rewards</b>: Many environments provide limited feedback, making it difficult for agents to learn effective policies. RND helps by providing intrinsic rewards based on prediction errors of a randomly initialized network, encouraging exploration.
# - <b>Efficient Policy Optimization</b>: PPO uses a clipped surrogate objective to ensure stable and efficient updates to the policy, preventing large deviations that could destabilize training.
#
# Submission requirements:
# * Please do not modify anything outside of the `### BEGIN SOLUTION ... ### END SOLUTION` blocks (if you feel it might be useful somewhere, ask on slack).
# * Don't use `tqdm.notebook` or `tqdm.auto`, just plain `tqdm`.
# * Don't use additional libraries than provided - see/run `hw4-rl_hw_tester_student` for reference.
# * Use only provided context objects and variables for each solution (common: numpy, torch) - example: (numpy, torch, self, x, action) - see/run `hw4-rl_hw_tester_student` for reference.
# * Include your full name in the designated solution field **Student\'s name** - **required**.
# * Use the designated solution field **Message** for additional information to assist the reviewing instructor - optional.
# * It should be possible to execute the notebook from top to bottom when loaded in Colab with a GPU in a reasonable amount of time (perfect solution about 2h).
# * Plots should either be images embedded in cell outputs (in a way that shows correctly when loading the notebook from the file, without executing it), or attached with the exported .ipynb notebook in a .zip file (screenshots are admissible, but prefer exporting with e.g. `plt.savefig()`). At the end of the notebook method `save_static_plots_in_notebook` will embed sufficient plots automatically.
# * Please submit your solution as a notebook with saved cell outputs.
# * There is one provided completed solution for reference which has its own test - `PPOT compute_advantages`.
# * **(IMPORTANT) Make sure that every correctly completed solution passes its designated test in `hw4-rl_hw_tester_student` notebook.**

# %% [markdown]
# ## Installation
# You will have to restart session on Google Colab
#
# (when configuring local env refer to local_config_instructions document)

# %%
# works for Google Colab
# !pip install tyro 
# !pip install imageio[ffmpeg]
# !pip install pufferlib==1.0
# !pip install --upgrade tensorboard
# !pip install "https://github.com/balrog-ai/nle/releases/download/fair/nle-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl"
# !pip install minihack

# %% [markdown]
# ### Alternative local installation tips
# (Ubuntu Linux)
#
# sudo apt update && sudo apt upgrade -y
#
# sudo apt install python3 python3-pip python3-venv build-essential cmake git -y \
# sudo apt install libffi-dev libbz2-dev liblzma-dev zlib1g-dev libncurses5-dev libncursesw5-dev -y \
# sudo apt install flex bison
#
# conda create -n rl_hw python=3.10 \
# conda activate rl_hw
#
# (in env)
#
# pip install tyro \
# pip install imageio[ffmpeg] \
# pip install pufferlib==1.0 \
# pip install --upgrade tensorboard \
# pip install minihack
#
# other libs can be installed via “conda install”

# %% [markdown]
# ## Imports

# %%
import random
import argparse
import time
from functools import partial
from collections import deque
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from gym.wrappers.normalize import RunningMeanStd
from torch.utils.tensorboard import SummaryWriter

# RL library for vectorized environments
import pufferlib
import pufferlib.vector
import pufferlib.emulation

# %% [markdown]
# ## Loggers

# %%
import plotly.graph_objects as go
import plotly.io as pio
import matplotlib.pyplot as plt
from google.colab import output # only for Google Colab
output.enable_custom_widget_manager()

class TrainingLolcaLogger:
    def __init__(self):
        self.loss = self.init_line_plot(title='Training entropy loss', xaxis_title='Global step')
        self.ave_er = self.init_line_plot(title='Training average episode return', xaxis_title='Global step')
        self.ave_cr = self.init_line_plot(title='Training average curiosity reward', xaxis_title='Global step')
        self.sps = self.init_line_plot(title='Steps Per Socond', xaxis_title='Global step')

        self.loss.data[0].name = f'PPO'
        self.loss.data[1].name = f'PPO+RND'
        self.ave_er.data[0].name = f'PPO'
        self.ave_er.data[1].name = f'PPO+RND'
        self.ave_cr.data[0].name = f'PPO+RND'
        self.sps.data[0].name = f'PPO'
        self.sps.data[1].name = f'PPO+RND'


    def init_line_plot(
        self,
        title,
        x=None, xaxis_title=None,
        yaxis_title=None, yaxis_type='linear',
        mode='lines'
    ):
        fig = go.Figure()
        fig.update_layout(
            title=title, title_x=0.5,
            xaxis_title=xaxis_title, yaxis_title=yaxis_title,
            height=400, width=1500, margin=dict(b=10, t=60)
        )
        fig.update_yaxes(type=yaxis_type)
        for _ in range(25):
            fig.add_trace(go.Scatter(x=[], y=[], showlegend=True, mode=mode))

        fig_widget = go.FigureWidget(fig)
        display(fig_widget)
        return fig_widget

    def plot_ppo_loss(self, loss, step):
        self.loss.data[0].y += (loss, )
        self.loss.data[0].x += (step, )

    def plot_rnd_loss(self, loss, step):
        self.loss.data[1].y += (loss, )
        self.loss.data[1].x += (step, )

    def plot_ppo_er(self, er, step):
        self.ave_er.data[0].y += (er, )
        self.ave_er.data[0].x += (step, )

    def plot_rnd_er(self, er, cr, step):
        self.ave_er.data[1].y += (er, )
        self.ave_er.data[1].x += (step, )
        self.ave_cr.data[0].y += (cr, )
        self.ave_cr.data[0].x += (step, )
    
    def plot_ppo_sps(self, sps, step):
        self.sps.data[0].y += (sps, )
        self.sps.data[0].x += (step, )
    
    def plot_rnd_sps(self, sps, step):
        self.sps.data[1].y += (sps, )
        self.sps.data[1].x += (step, )

    def save_static_plots_in_notebook(self):
        # Convert each FigureWidget to a regular Figure and display it using matplotlib
        static_loss = go.Figure(self.loss)
        static_ave_er = go.Figure(self.ave_er)
        static_ave_cr = go.Figure(self.ave_cr)
        static_sps = go.Figure(self.sps)

        # Plot loss
        plt.figure()
        for trace in static_loss.data:
            plt.plot(trace.x, trace.y, label=trace.name)
        plt.title("Training entropy loss")
        plt.xlabel("Global step")
        plt.ylabel("Loss")
        plt.legend()
        plt.show()

        # Plot average episode return
        plt.figure()
        for trace in static_ave_er.data:
            plt.plot(trace.x, trace.y, label=trace.name)
        plt.title("Training average episode return")
        plt.xlabel("Global step")
        plt.ylabel("Episode Return")
        plt.legend()
        plt.show()

        # Plot curiosity reward
        plt.figure()
        for trace in static_ave_cr.data:
            plt.plot(trace.x, trace.y, label=trace.name)
        plt.title("Training average curiosity reward")
        plt.xlabel("Global step")
        plt.ylabel("Curiosity Reward")
        plt.legend()
        plt.show()

        # Plot SPS
        plt.figure()
        for trace in static_sps.data:
            plt.plot(trace.x, trace.y, label=trace.name)
        plt.title("Steps per socond")
        plt.xlabel("Global step")
        plt.ylabel("SPS")
        plt.legend()
        plt.show()


tlol = TrainingLolcaLogger()
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a2fa5816-5ab8-4305-83f2-e09acd155480',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '2922431e-798e-474d-9944-b2a093ae5cab',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '4211f2fe-4efd-4e69-8deb-8bf7b64d6b0d',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '92fd9777-d017-45a4-b928-793da4c2bf52',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '84e754a7-e642-46d3-9c1d-62e50923a4c1',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '686509b0-7cd2-4e3c-8449-161fcc6cdc77',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a8e9d601-8a26-4820-8302-f3e2a546fd37',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '0e4412dc-ef44-4393-b2c1-2abc92382dbe',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5220b181-dda8-415b-96d5-74b3c002eb90',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '6b464dfe-894c-49ff-9509-d2215f95c12e',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '2c106b46-ed53-4870-ab9e-92c0cd86c636',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5fbfcf31-06f2-423b-8399-9ba842343909',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e0617726-c3ce-48d1-ab3c-8c4897958b03',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3225e7df-2fea-499a-bde6-157f9014ad46',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '59cc2713-f8bf-49be-9522-5d5031b37997',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '0d00e82c-7b15-4e8b-9b9d-5fd1cce464de',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '2c49badd-c59f-4393-8d08-89946773acd0',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '6f198e0a-e536-484b-a74a-de56fc9fb89d',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'fcc8c360-4abb-4ba3-99a4-0d2b12e12e3b',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8c2154fb-d3de-44a2-a1b0-76c2bd64d9c1',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c5041fb2-a5d6-48b1-8f72-2ff2be436e2d',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '17777488-dc05-488a-990a-19e4d6e48673',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '53568d1d-3e1e-42d1-8f5f-042d7866c72d',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '0c1f8d85-3453-4565-9a59-c43379b8b771',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c20ae85e-bd0a-4202-bc86-b7fa9f84f96b',
#               'x': [],
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Training entropy loss', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Global step'}},
#                'yaxis': {'type': 'linear'}}
# })
# FigureWidget({
#     'data': [{'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a9ff0bdf-c203-485e-96fa-98d86877e49a',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '2fed719f-dcf9-4687-aad9-b6a0c03466da',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '98b0d8b8-2795-4b02-b4d2-3e0134cfc56f',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'fe8a1b22-c87f-4e6e-ad54-17c0643c72fa',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '6fa63936-2190-4d11-8bce-a5cdfa093b33',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '150110fe-e538-4e7e-9dc0-3712e94079a2',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '41c974ca-9ded-4224-8cf4-832328cb14af',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5d141b29-908a-42c0-955a-c9262694bb6b',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e0af6bf3-6c58-4bdf-a8c5-418dcc146481',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c1c243ff-ada2-40af-9d20-fd72b841194a',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'b883d7ec-1f54-4a76-b072-3c9c42a9255e',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'ce0b97ae-6835-47c3-8bbf-a73fc12f3d3a',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '47ae6819-601c-4efa-b889-97f7ddde03b4',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '63ead5c1-477c-4a1b-a6ca-018004cb21a8',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'cb0b8faf-e091-4e48-ba45-e51f137b9711',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '48562e2b-3734-400e-a50f-a7bc747a2c8c',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '0ebcbda5-3678-462b-bfcc-e05b274ca39c',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '65460976-67d6-4b1d-bb6b-361c6ba17d6e',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '37985e7e-4d17-44a0-9f49-a76e78fa7b4c',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '48534f6a-ad9a-466d-9708-8f636fc24d41',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '630d8643-9880-4acb-9492-04873aaf83ca',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3de17abf-cde8-443f-b1dc-c1ae7f52ba78',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '50424ce8-a573-4bdb-9c1e-6385a23ab691',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3ed0fc36-4e09-42dd-9237-88c5041e42dc',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8478ed8e-9855-4026-be79-68a3c40aafc4',
#               'x': [],
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Training average episode return', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Global step'}},
#                'yaxis': {'type': 'linear'}}
# })
# FigureWidget({
#     'data': [{'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a276460e-dd55-4404-8080-5b4d455ae0c8',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '742391f8-0273-4a77-93bd-5ff6ff0a4813',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a4e4d893-4fe7-4a19-a4c9-b6067ebb462f',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8369a40e-586e-4120-bc34-84be1272e1d0',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '983552c0-79f3-4816-8ab5-a0fb70a59b51',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '14f3a033-f7c2-4154-8bf5-6b0fe2ffa4b6',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c6a171c5-da79-4f30-85ea-c2c983ae1ae6',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '6d30b94a-3aea-4cd1-a14a-85017fe5a3d9',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '1c8aaced-7c30-422d-ae97-c58712d6a86e',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'b520bd75-0e18-4ad0-9bd9-b68ad9028182',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'ed4512bd-e7d6-4162-b8ee-ac09188fb412',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'f6bf0bcb-9f7e-4fc2-a15a-84fea3226f08',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'b62016f0-d721-42fd-9c8e-430a5b373db8',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'bcebeac1-6c50-47a5-a129-a8548076ab2e',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '89c12605-27e3-4f0d-a4b4-83a1d3a6bf91',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a41002eb-d77b-48d3-8da4-786653d5ba5e',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3b506abb-ca54-4f93-b0f9-11167fda3763',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '306942df-c7f1-4e23-85fd-131c403997ed',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e606b351-435a-4db4-a59b-b52a8ec2acdf',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'fff6976e-b3d2-41e8-b7cc-9bef801a5f51',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7eda205c-963c-41ba-8cf9-3248f5d3b09f',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3b984394-d798-49d8-9ba0-f568dd950066',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '35f3bacb-6b99-4080-a2e6-6a06ae2a10b0',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7358b8fc-e8c7-46ca-90c1-77a1843046fd',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '46e32c10-78cf-4c19-b9b9-b1b07065213f',
#               'x': [],
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Training average curiosity reward', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Global step'}},
#                'yaxis': {'type': 'linear'}}
# })
# FigureWidget({
#     'data': [{'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '491ed873-6fff-454b-8c04-1e577ad71bde',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8a9bfd1c-3d71-489d-b698-2e75db5eb3a1',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5a4487a6-8ca3-4ad8-b910-df28b81d6e55',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'fae7ce7e-4f7f-4a94-8d1f-a63891833ae7',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '295784b3-b118-473f-9c9b-6fe9d49664ee',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '499011cd-fddc-4cd4-8f40-cf558bace683',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c0199770-4477-41b5-901c-4f13d1ce244c',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5a2e67d8-bbff-4e84-bffa-efda169bc347',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '114b6e0e-6e8e-42b6-b638-881a9066a70f',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7533ec1e-cfbc-45f9-99a0-c2bce7135f3e',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '53b986a3-a2d9-4973-a6c5-ab5bdf219a83',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '9a85bf61-2577-4cf2-b5de-3ce6b2649a18',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '4e9e8381-03c6-417e-ae1b-a48340fe01db',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7fce9a76-06d3-43df-afda-401d0eb10127',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'ea7fa76b-3fa9-41a8-8afa-b29011f34654',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e5f70341-1ea1-4b59-af8e-820fd1a2ad83',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'b47e4be8-6cfe-414f-ae87-688bb5abb26e',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '1ba7a931-5ce2-4c07-b714-8c9d206a8d6d',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7204cf16-7374-4e05-955f-61fee032c532',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'be1c9773-377a-465b-9a65-6683070d5ea2',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '2212813d-5636-470d-a8d9-468ffdc63f3e',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a5f3f0ff-a4c1-42e3-8dcc-7718733740b9',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '2cadbb0b-f82a-4363-9bd2-399ad14f5878',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '07aeff8f-a013-4a1d-bc59-acf9216e5734',
#               'x': [],
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '74bd90a7-c69a-47b1-b6dc-e1344df860f2',
#               'x': [],
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Steps Per Socond', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Global step'}},
#                'yaxis': {'type': 'linear'}}
# })

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs --verbosity=1
# Out:
#       <iframe id="tensorboard-frame-fcf39472d62c3718" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-fcf39472d62c3718");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Argument Parsing

# %%
def str2bool(v):
    if isinstance(v, bool):
        return v
    if isinstance(v, str) and v.lower() in ("true",):
        return True
    elif isinstance(v, str) and v.lower() in ("false",):
        return False
    else:
        raise argparse.ArgumentTypeError("Boolean value expected")


@dataclass
class Args:
    exp_name: str = "ppo_rnd"
    """the name of this experiment"""
    seed: int = 1
    """seed of the experiment"""
    torch_deterministic: str2bool = True
    """if toggled, `torch.backends.cudnn.deterministic=False`"""
    cuda: str2bool = True
    """if toggled, cuda will be enabled by default"""
    track: str2bool = False
    """if toggled, this experiment will be tracked with Weights and Biases"""
    wandb_project_name: str = "cleanRL"
    """the wandb's project name"""
    wandb_entity: str = None
    """the entity (team) of wandb's project"""
    capture_video: str2bool = False
    """whether to capture videos of the agent performances (check out `videos` folder)"""

    # Algorithm specific arguments
    env_id: str = "MiniHack-KeyRoom-Dark-S5-v0"
    """the id of the environment"""
    max_episode_steps: int = None
    """number of episode steps"""
    total_timesteps: int = 5000000
    """total timesteps of the experiments"""
    learning_rate: float = 2e-4
    """the learning rate of the optimizer"""
    num_envs: int = 128
    """the number of parallel game environments"""
    num_workers: int = 16
    """the number of workers"""
    num_steps: int = 128
    """the number of steps to run in each environment per policy rollout"""
    anneal_lr: str2bool = True
    """Toggle learning rate annealing for policy and value networks"""
    gamma: float = 0.999
    """the discount factor gamma"""
    gae_lambda: float = 0.95
    """the lambda for the general advantage estimation"""
    num_minibatches: int = 8
    """the number of mini-batches"""
    update_epochs: int = 8
    """the K epochs to update the policy"""
    norm_adv: str2bool = True
    """Toggles advantages normalization"""
    clip_coef: float = 0.1
    """the surrogate clipping coefficient"""
    clip_vloss: str2bool = True
    """Toggles whether or not to use a clipped loss for the value function, as per the paper."""
    ent_coef: float = 0.001
    """coefficient of the entropy"""
    vf_coef: float = 0.5
    """coefficient of the value function"""
    max_grad_norm: float = 40
    """the maximum norm for the gradient clipping"""
    target_kl: float = None
    """the target KL divergence threshold"""
    penalty_step: float = 0.0
    """the penalty for each env step"""
    value_bootstrap: str2bool = True
    """Value bootstrapping"""

    # RND arguments
    update_proportion: float = 1.0
    """proportion of exp used for predictor update"""
    int_coef: float = 0.1
    """coefficient of extrinsic reward"""
    ext_coef: float = 1.0
    """coefficient of intrinsic reward"""
    int_gamma: float = 0.99
    """Intrinsic reward discount rate"""
    num_iterations_obs_norm_init: int = 5
    """number of iterations to initialize the observations normalization parameters"""
    forward_coef: float = 0.1
    """weight on modelling loss (ie convergence of predictor)"""

    # to be filled in runtime
    batch_size: int = 0
    """the batch size (computed in runtime)"""
    minibatch_size: int = 0
    """the mini-batch size (computed in runtime)"""
    num_iterations: int = 0
    """the number of iterations (computed in runtime)"""

# %% [markdown]
# ## RecordEpisodeStatistics, RewardForwardFilter, layer_init

# %%
class RecordEpisodeStatistics:
    def __init__(self, env, deque_size=100):
        self.env = env
        self.num_envs = getattr(env, "num_envs", 1)
        self.episode_returns = None
        self.episode_lengths = None

    def __getattr__(self, name):
        return getattr(self.env, name)

    def reset(self, **kwargs):
        observations, infos = self.env.reset(**kwargs)
        self.episode_returns = np.zeros(self.num_envs, dtype=np.float32)
        self.episode_lengths = np.zeros(self.num_envs, dtype=np.int32)
        self.lives = np.zeros(self.num_envs, dtype=np.int32)
        self.returned_episode_returns = np.zeros(self.num_envs, dtype=np.float32)
        self.returned_episode_lengths = np.zeros(self.num_envs, dtype=np.int32)
        return observations, {}

    def step(self, action):
        observations, rewards, terminatedes, truncatedes, infos = self.env.step(action)
        self.episode_returns += rewards
        self.episode_lengths += 1
        self.returned_episode_returns[:] = self.episode_returns
        self.returned_episode_lengths[:] = self.episode_lengths
        self.episode_returns *= 1 - terminatedes
        self.episode_lengths *= 1 - terminatedes

        infos = {}
        infos["r"] = self.returned_episode_returns
        infos["l"] = self.returned_episode_lengths

        return (
            observations,
            rewards,
            terminatedes,
            truncatedes,
            infos,
        )


class RewardForwardFilter:
    def __init__(self, gamma):
        self.rewems = None
        self.gamma = gamma

    def update(self, rews):
        if self.rewems is None:
            self.rewems = rews
        else:
            self.rewems = self.rewems * self.gamma + rews
        return self.rewems


# ALGO LOGIC: initialize agent here:
def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer

# %% [markdown]
# ## Create Envs

# %%
import gymnasium
from nle.env.base import NLE

class NLETimeLimit(gymnasium.Wrapper):
    def __init__(self, env: gymnasium.Env):
        super().__init__(env)

    def step(self, action):
        obs, reward, terminated, truncated, info = super().step(action)
        if "end_status" in info:  # Add safety check
            if info["end_status"] == NLE.StepStatus.ABORTED:
                truncated = True
        return obs, reward, terminated, truncated, info


def env_creator(args):
    '''NetHack binding creation function'''
    import minihack
    import gym
    import shimmy
    from pufferlib.environments.minihack.environment import MinihackWrapper, EXTRA_OBS_KEYS

    obs_key = minihack.base.MH_DEFAULT_OBS_KEYS + EXTRA_OBS_KEYS
    kwargs = dict(
        observation_keys=obs_key,
        penalty_step=args.penalty_step,
    )
    env = gym.make(args.env_id, **kwargs)
    env = shimmy.GymV21CompatibilityV0(env=env)
    env = NLETimeLimit(env)
    env = MinihackWrapper(env)
    return pufferlib.emulation.GymnasiumPufferEnv(env=env)

def create_env(args):
    env = pufferlib.vector.make(partial(env_creator, args), batch_size=args.num_envs, num_envs=args.num_envs, num_workers=args.num_workers, backend=pufferlib.vector.Multiprocessing)
    env = RecordEpisodeStatistics(env)
    return env

# %% [markdown]
# ## VideoRecorder

# %%
import imageio
import pathlib
from PIL import Image, ImageDraw, ImageFont
from IPython.display import Video


class VideoRecorder:
    def __init__(self, env, directory, size=(512, 512)):
        self.env = env
        self._directory = pathlib.Path(directory).expanduser()
        self._directory.mkdir(exist_ok=True, parents=True)
        self._size = size
        self._frames = None

    def __getattr__(self, name):
        return getattr(self.env, name)

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        self._frames = [self.render_image()]
        return obs, info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        self._frames.append(self.render_image())

        if terminated or truncated:
            self._save()

        return obs, reward, terminated, truncated, info

    def _save(self):
        if self._frames:
            filename = str(self._directory / "trajectory.mp4")
            imageio.mimsave(filename, self._frames)

    def render_image(self):
        obs = self.env.env.env.gym_env.last_observation
        obs_keys = self.env.env.env.gym_env._observation_keys
        tty_chars = obs[obs_keys.index("tty_chars")]
        tty_colors = obs[obs_keys.index("tty_colors")]
        tty_cursor = obs[obs_keys.index("tty_cursor")]
        image = tty_render(tty_chars, tty_colors, tty_cursor, font_path=None)
        image = image.resize((600, 430))
        return np.asanyarray(image)


def tty_render(chars, colors, cursor=None, font_size=16, font_path="Hack-Regular.ttf"):
    # Create font object
    font = ImageFont.truetype(font_path, font_size) if font_path else ImageFont.load_default()

    height, width = chars.shape
    line_height = font_size + 6
    line_width = font_size - 6

    # Create image
    img = Image.new("RGB", (width * line_width, height * line_height), color="black")
    draw = ImageDraw.Draw(img)

    color_palette = [
        (0, 0, 0),
        (255, 0, 0),
        (0, 255, 0),
        (255, 255, 0),
        (0, 0, 255),
        (255, 0, 255),
        (0, 255, 255),
        (255, 255, 255),
    ]

    color_palette = [
        # Standard colors (30-37)
        (0, 0, 0),  # Black
        (255, 0, 0),  # Red
        (0, 255, 0),  # Green
        (255, 255, 0),  # Yellow
        (0, 0, 255),  # Blue
        (255, 0, 255),  # Magenta
        (0, 255, 255),  # Cyan
        (255, 255, 255),  # White
        # Bright colors (90-97)
        (128, 128, 128),  # Bright Black / Gray
        (255, 85, 85),  # Bright Red
        (85, 255, 85),  # Bright Green
        (255, 255, 85),  # Bright Yellow
        (85, 85, 255),  # Bright Blue
        (255, 85, 255),  # Bright Magenta
        (85, 255, 255),  # Bright Cyan
        (255, 255, 255),  # Bright White
    ]

    if cursor is None:
        cursor = (-1, -1)
    cursor = tuple(cursor)

    rows, cols = chars.shape
    y = 0
    for i in range(rows):
        x = 0
        for j in range(cols):
            draw.text((x, y), chr(chars[i, j]), fill=color_palette[colors[i, j] % 16], font=font)
            if cursor == (i, j):
                draw.text((x, y + 2), "_", fill=color_palette[7], font=font)

            x += line_width
        y += line_height

    return img


@torch.no_grad
def play(agent, args):
    env = env_creator(args)
    env = VideoRecorder(env, ".")
    obs, info = env.reset()

    device = next(agent.parameters()).device

    steps = 0
    reward = 0.0
    total_reward = 0.0

    while True:
        action = agent.get_action_and_value(torch.Tensor(obs).unsqueeze(0).to(device))[0][0].item()
        obs, reward, terminated, truncated, info = env.step(action)

        steps += 1
        total_reward += reward

        if not (terminated or truncated):
            continue

        break
    print(f"reward: {reward}, steps: {steps}")
    env.close()
    return info

# %% [markdown]
# # Task 1: PPO

# %% [markdown]
# ## Motivation
# Policy optimization methods in reinforcement learning face two major challenges: <b>sample inefficiency</b> and <b>training instability</b>. On-policy methods require fresh data collection for each policy update, making them sample inefficient since data cannot be reused once the policy changes. Additionally, early policy gradient approaches often suffered from instability during training, as large parameter updates could lead to performance collapse.
#
# <b>Trust Region Policy Optimization (TRPO)</b> attempted to address these issues by introducing constraints on policy updates. However, TRPO's reliance on complex second-order optimization made it computationally expensive and difficult to implement. This led to the development of <b>Proximal Policy Optimization (PPO)</b>, which maintains TRPO's benefits while simplifying the implementation.
#
# ## Core Idea
#
# The fundamental idea behind PPO is to prevent excessive policy changes during training by implementing a "clip" mechanism. This clipping function ensures that the ratio between new and old policies stays within a small range, typically $[1-\epsilon,1+\epsilon]$ where $\epsilon$ is usually between 0.1 and 0.2. When the policy update results in a ratio outside this range, the clipping function restricts the change, effectively creating a trust region without the computational complexity of second-order methods
#
#
# PPO operates in two main phases: data collection and optimization. During data collection, the algorithm gathers trajectories using the current policy. In the optimization phase, it performs multiple epochs of minibatch updates on this collected data. $\pi_{\theta_{old}(a_t|s_t)}$ are outputs of the actor when we collected the data, $\pi_{\theta_{old}(a_t|s_t)}$ are the outputs of the policy after we performed minibatch update.
#
# The PPO objective function is defined as:
#
# $$ L^{CLIP}(\theta)=\hat {\mathbb{E}}_t \left [ \min(r_t(\theta) \hat A_t, \text{clip}(r_t(\theta), 1-\epsilon, 1+\epsilon)\hat A_t) \right ] $$
#
# Here, $t$ indexes the time steps in the collected trajectories, $A_t$ denotes the estimated advantage function, and the probability ratio is defined as:
#
# $$r_t(\theta) = {\pi_\theta(a_t|s_t) \over \pi_{\theta_{old}}(a_t|s_t)}$$
#
# The hat over $A_t$ signifies that it is an **estimator** of the advantage function, and the hat over $E_t$ indicates an **empirical average** used to approximate the true expectation.
#
# The objective function maximizes the expected return by increasing the likelihood of actions with positive advantages ($A_t > 0$) while decreasing the likelihood of actions with negative advantages ($A_t < 0$). This balanced approach facilitates stable policy improvement. The expectation operator $\mathbb{E}_t$ indicates averaging over the sampled trajectories during data collection.
#
# ## Implementation Details
#
# 1. <b>Actor</b>: The actor represents the policy, $\pi_\theta(a_t|s_t)$, which maps states to a probability distribution over actions. It is responsible for deciding what action the agent should take in a given state. During training, the actor is updated to maximize the PPO objective function by either increasing or decreasing the likelihood of actions based on their estimated advantages.
#
# 2. <b>Critic</b>: The critic estimates the value of a state, typically using a value function $V_{\phi}(s_t)$. This value function helps determine how "good" a particular state is by predicting the expected cumulative reward from that state onward. The critic is trained to minimize the mean squared error between its predictions and the actual discounted returns observed during training.
#
# 3. <b>Data Collection</b>: In this phase, trajectories are collected by having the agent interact with the environment using its current policy $\pi_{\theta_{old}}(a_t|s_t)$. Each trajectory contains sequences of states, actions, rewards, and log probabilities of actions under the current policy. These trajectories are used to compute several key quantities:
#   - Discounted Returns: The cumulative rewards from each state onward.
#
#  $$ G_t = \sum_{t=0}^{∞} \gamma^t r_t $$
#  $$ G_t = \sum_{t=0}^k \gamma^t r_t + V_{\phi}(s_{k+1})  $$
#
#   - Advantages: The difference between observed returns and predicted state values. PPO uses Generalized Advantage Estimation (GAE) to compute these advantages efficiently and reduce variance.
#
#  $$ \hat{A}_t^{GAE(\gamma, \lambda)} = \sum_{l=0}^∞ (\gamma \lambda)^l \delta_{t+l}^V$$
#  $$\delta_t^V=-V(s_t) + r_t + \gamma V(s_{t+1})$$
#
# 4. <b>Optimization</b>: Once data is collected, PPO performs multiple epochs of minibatch updates on this data to improve both the actor (policy network) and the critic (value network). The optimization process involves:
#   - Policy Update (Actor): The PPO objective function is used to update the policy network.
#
#  $$ L^{CLIP}(\theta)=\hat {\mathbb{E}}_t \left [ \min(r_t(\theta) \hat A_t, \text{clip}(r_t(\theta), 1-\epsilon, 1+\epsilon)\hat A_t) \right ] $$
#
#   - Value Function Update (Critic): The critic network is updated by minimizing a mean squared error loss. Here, $G_t$ represents the discounted return or target value for state $s_t$
#
#  $$L^{VF}=\frac{1}{2N}\sum_{t=1}^{N}(V_{\phi}(s_t)-G_t)^2$$
#
#   - Entropy Regularization: To encourage exploration and prevent premature convergence to suboptimal policies, an entropy term is often added to the loss function.
#
#  $$L^{ENTROPY}=-\beta \sum_{\alpha} \pi_{\theta}(a|s) \text{log} \pi_{\theta}(a|s)$$
#
# ## Training Loop
# The overall training loop for PPO can be summarized as follows:
# - Collect trajectories using the current policy.
# - Compute discounted returns and advantages using GAE.
# - Perform multiple epochs of minibatch updates on both:
#   - The actor using the clipped surrogate objective.
#   - The critic using mean squared error loss.
# - Repeat until convergence or until a predefined number of iterations is reached.
#
# ## References
#
# - PPO: [J. Schulman et al., "Proximal Policy Optimization Algorithms." arXiv preprint arXiv:1707.06347, 2017.](https://arxiv.org/abs/1707.06347.pdf)
# - TRPO: [Schulman, John, et al. "Trust region policy optimization." International conference on machine learning. 2015.](http://proceedings.mlr.press/v37/schulman15.pdf)
# - GAE: [Schulman, John, et al. "High-dimensional continuous control using generalized advantage estimation."](https://arxiv.org/abs/1506.02438)

# %% [markdown]
# ## Implement Agent class
#
# We will use a shared encoder and three linear networks for the actor and two critics respectively. The encoder network consists of three parts:
# 1. A `blstats_net` that processes game statistics through an embedding layer,
# 2. A convolutional network (`chars_net`) that processes the game's character-based display after embedding each character,
# 3. A combination layer that merges and projects down these features.
#
# Projected features are then fed into three output heads:
# - actor that decides actions (policy),
# - critic that estimates extrinsic rewards (rewards from our environment),
# - critic that estimates intrinsic rewards (for curiosity-driven exploration).

# %%
class Agent(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.dtype = pufferlib.pytorch.nativize_dtype(env.emulated)

        self.blstats_net = nn.Sequential(
            nn.Embedding(256, 32),
            nn.Flatten(),
        )

        self.char_embed = nn.Embedding(256, 32)
        self.chars_net = nn.Sequential(
            layer_init(nn.Conv2d(32, 32, 5, stride=(2, 3))),
            nn.ReLU(),
            layer_init(nn.Conv2d(32, 64, 5, stride=(1, 3))),
            nn.ReLU(),
            layer_init(nn.Conv2d(64, 64, 3, stride=1)),
            nn.ReLU(),
            nn.Flatten(),
        )

        self.proj = nn.Linear(864+960, 256)
        self.actor = layer_init(nn.Linear(256, env.single_action_space.n), std=0.01)
        self.critic_ext = layer_init(nn.Linear(256, 1), std=0.01)
        self.critic_int = layer_init(nn.Linear(256, 1), std=0.01)

    def encode_observations(self, x):
        x = x.type(torch.uint8) # Undo bad cleanrl cast
        x = pufferlib.pytorch.nativize_tensor(x, self.dtype)

        blstats = torch.clip(x['blstats'] + 1, 0, 255).int()
        blstats = self.blstats_net(blstats)

        chars = self.char_embed(x['chars'].int())
        chars = torch.permute(chars, (0, 3, 1, 2))
        chars = self.chars_net(chars)

        concat = torch.cat([blstats, chars], dim=1)
        return self.proj(concat)

    def get_action_and_value(self, x, action=None):
        # 1. encode the observations using the existing code
        # 2. pass this hidden state through the actor network to get action logits,
        # 3. create a torch.distributions.categorical.Categorical distribution from these logits
        # 4. either sample an action (if none is provided) or use the given action,
        # 5. The method should return a tuple containing:
        #     (
        #       the action,
        #       its log probability,
        #       the entropy of the distribution,
        #       and the values from both critic networks (extrinsic and intrinsic)
        #     ).
        ### BEGIN SOLUTION - PPO get_action_and_value


        encoded_observation = self.encode_observations(x)

        action_logits = self.actor(encoded_observation)

        probs = torch.distributions.categorical.Categorical(logits = action_logits)

        if action is None:
            action = probs.sample()

        log_prob = probs.log_prob(action)
        entropy_prop = probs.entropy()

        extrinsic_output = self.critic_ext(encoded_observation)

        intrinsic_output = self.critic_int(encoded_observation)

        ### END SOLUTION
        return (
            action,
            log_prob,
            entropy_prop,
            extrinsic_output,
            intrinsic_output
        )

    def get_value(self, x):
        # simply encode the observations and return the outputs of both critic networks (extrinsic and intrinsic).
        ### BEGIN SOLUTION - PPO get_value

        encoded_observation = self.encode_observations(x)

        extrinsic_output = self.critic_ext(encoded_observation)

        intrinsic_output = self.critic_int(encoded_observation)

        ### END SOLUTION
        return extrinsic_output, intrinsic_output

# %% [markdown]
# ## PPO Trainer

# %%
class PPOTrainer:
    def __init__(self, args, writer, env, agent, tlol:TrainingLolcaLogger):
        self.args = args
        self.writer = writer
        self.env = env
        self.agent = agent
        self.device = next(agent.parameters()).device
        self.tlol = tlol

        self.combined_parameters = list(self.agent.parameters())
        self.optimizer = optim.Adam(
            self.combined_parameters,
            lr=self.args.learning_rate,
            eps=1e-5,
        )

        self.obs = torch.zeros((self.args.num_steps, self.args.num_envs) + self.env.single_observation_space.shape).to(self.device)
        self.actions = torch.zeros((self.args.num_steps, self.args.num_envs) + self.env.single_action_space.shape).to(self.device)
        self.logprobs = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)
        self.rewards = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)
        self.dones = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)
        self.time_outs = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)
        self.ext_values = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)

        self.er_counter = 0
        self.av_er_interval = 20

    def compute_advantages(self, next_obs, next_done):
        """
        Your task is to implement the computation of advantages using Generalized Advantage Estimation (GAE).

        Key Concepts:
        - **Generalized Advantage Estimation (GAE):** A technique to compute advantage values that balances bias and variance
        using a combination of temporal difference (TD) errors and discounted returns.
        - **Temporal Difference Error (Delta):** Measures the difference between the predicted value and the observed reward
        plus the discounted value of the next state.
        - **Discount Factor (gamma):** Determines how much future rewards are taken into account.
        - **GAE Lambda (gae_lambda):** Controls the trade-off between bias and variance in advantage estimation.

        Available Variables:
        - `self.rewards`: A tensor containing rewards for each timestep in the trajectory.
        - `self.dones`: A tensor indicating whether each timestep is terminal.
        - `self.ext_values`: A tensor containing value estimates for each timestep in the trajectory.
        - `self.agent.get_value(obs)`: A method that returns the value estimate for a given observation.
        - `self.args.gamma`: The discount factor for future rewards.
        - `self.args.gae_lambda`: The GAE lambda parameter.

        Implementation Details:
        - Use a loop to iterate backward through time steps (`range(self.args.num_steps)`).
        - Compute temporal difference error (`delta`) at each step.
        - Use GAE to compute advantages recursively, starting from the last timestep.
        - Ensure that computations handle terminal states appropriately using `next_done` and `self.dones`.
        """

        with torch.no_grad():
            next_value_ext, _ = self.agent.get_value(next_obs)
            # Completed solution in studnet version
            ### BEGIN SOLUTION - PPOT compute_advantages
            next_value_ext = next_value_ext.reshape(1, -1)

            ext_advantages = torch.zeros_like(self.rewards, device=self.device)
            ext_lastgaelam = 0

            for t in reversed(range(self.args.num_steps)):
                if t == self.args.num_steps - 1:
                    ext_nextnonterminal = 1.0 - next_done
                    ext_nextvalues = next_value_ext
                else:
                    ext_nextnonterminal = 1.0 - self.dones[t + 1]
                    ext_nextvalues = self.ext_values[t + 1]

                ext_delta = (self.rewards[t] + self.args.gamma * ext_nextvalues * ext_nextnonterminal - self.ext_values[t])
                ext_advantages[t] = ext_lastgaelam = (ext_delta + self.args.gamma * self.args.gae_lambda * ext_nextnonterminal * ext_lastgaelam)
            ### END SOLUTION
        return ext_advantages

    def compute_policy_loss(self, mb_advantages, ratio):
        """
        Compute the clipped policy loss for Proximal Policy Optimization (PPO).

        Key Concepts:
        - PPO optimizes a policy by maximizing a clipped objective function to ensure stable training.
        This method computes the negative of that objective function to facilitate minimization, as 
        required by Torch optimization frameworks.
        - **Policy Ratio (ratio):** The ratio of the probability of taking an action under the current policy
        to the probability under the old policy. This measures how much the policy has changed.
        - **Clipping:** A technique to limit the change in the policy ratio to a range defined by `clip_coef`
        (e.g., [1 - clip_coef, 1 + clip_coef]). This prevents excessively large updates that can destabilize training.
        - **Advantages (mb_advantages):** Precomputed advantage values that guide the direction of policy updates.

        Available Variables:
        - `self.args.clip_coef`: The clipping coefficient used to limit changes in the policy ratio.

        Expected Output:
        - Return a scalar tensor representing the computed clipped policy loss. This loss is minimized to maximize the PPO objective.
        """
        ### BEGIN SOLUTION - PPOT compute_policy_loss

        clipped = torch.clip(ratio, 1 - self.args.clip_coef, 1 + self.args.clip_coef) * mb_advantages

        ppo = torch.min(ratio * mb_advantages, clipped)

        ppo_average = torch.mean(ppo)

        pg_loss = - ppo_average

        ### END SOLUTION
        return pg_loss

    def compute_value_loss(self, new_values, returns):
        """
        Compute the value loss for a reinforcement learning agent.

        Key Concepts:
        - **Value Function:** A function that predicts the expected return (sum of future rewards) from a given state.

        Available Variables:
        - `new_values.view(-1)`: Reshape `new_values` into a flat tensor if necessary.
        - `returns`: Target returns for each timestep in the trajectory.

        Expected Output:
        - Return a scalar tensor `v_loss` representing the computed value loss.
        """
        ### BEGIN SOLUTION - PPOT compute_value_loss
        # Value loss

        n = new_values.shape[0]
        v_loss = (1 / (2 * n)) * torch.sum((new_values.view(-1) - returns) ** 2)

        ### END SOLUTION
        return v_loss

    def train(self):
        # ALGO Logic: Storage setup
        avg_returns = deque(maxlen=self.av_er_interval)

        # start the game
        global_step = 0
        start_time = time.time()
        next_obs = torch.Tensor(self.env.reset()[0]).to(self.device)
        next_done = torch.zeros(self.args.num_envs).to(self.device)
        next_time_out = torch.zeros(self.args.num_envs).to(self.device)
        num_updates = self.args.total_timesteps // self.args.batch_size

        for update in range(1, num_updates + 1):
            # Annealing the rate if instructed to do so.
            if self.args.anneal_lr:
                frac = 1.0 - (update - 1.0) / num_updates
                lrnow = frac * self.args.learning_rate
                self.optimizer.param_groups[0]["lr"] = lrnow

            for step in range(0, self.args.num_steps):
                global_step += 1 * self.args.num_envs
                self.obs[step] = next_obs
                self.dones[step] = next_done
                self.time_outs[step] = next_time_out

                # ALGO LOGIC: action logic
                with torch.no_grad():
                    value_ext, _ = self.agent.get_value(self.obs[step])
                    self.ext_values[step] = value_ext.flatten()
                    action, logprob, _, _, _ = self.agent.get_action_and_value(self.obs[step])

                self.actions[step] = action
                self.logprobs[step] = logprob

                # execute the game and log data.
                next_obs, reward, terminated, truncated, info = self.env.step(action.cpu().numpy())
                self.rewards[step] = torch.tensor(reward).to(self.device).view(-1)
                next_obs = torch.Tensor(next_obs).to(self.device)
                next_done = torch.Tensor(terminated).to(self.device)
                next_time_out = torch.Tensor(truncated).to(self.device)

                local_step = global_step - 1 * self.args.num_envs
                for idx, d in enumerate(terminated | truncated):
                    local_step+=1
                    if d:
                        avg_returns.append(info["r"][idx])
                        epi_ret = np.average(avg_returns)
                        epi_suc = np.average([1 if r > 0 else 0 for r in avg_returns])
                        if self.er_counter >= self.av_er_interval:
                            self.er_counter = 0
                            print(
                                f"local_step={local_step}, {self.av_er_interval}_avg_episodic_return={epi_ret}"
                            )
                            tlol.plot_ppo_er(epi_ret, local_step)
                        else:
                            self.er_counter += 1
                        self.writer.add_scalar("charts/avg_success_rate", epi_suc, local_step)
                        self.writer.add_scalar("charts/avg_episodic_return", epi_ret, local_step)
                        self.writer.add_scalar("charts/episodic_return", info["r"][idx], local_step)
                        self.writer.add_scalar("charts/episodic_length", info["l"][idx], local_step)

            if self.args.value_bootstrap:
                # Value bootstrapping is a technique that reduces the surprise for the critic in case
                # we're ending the episode by timeout. Intuitively, in this case the cumulative return for the last step
                # should not be zero, but rather what the critic expects. This improves learning in many envs
                # because otherwise the critic cannot predict the abrupt change in rewards in a timed-out episode.
                # What we really want here is v(t+1) which we don't have because we don't have obs(t+1) (since
                # the episode ended). Using v(t) is an approximation that requires that rew(t) can be generally ignored.
                self.rewards.add_(self.args.gamma * self.ext_values * self.time_outs)

            # bootstrap value if not done
            with torch.no_grad():
                ext_advantages = self.compute_advantages(next_obs, next_done)
                ext_returns = ext_advantages + self.ext_values

            # flatten the batch
            b_obs = self.obs.reshape((-1,) + self.env.single_observation_space.shape)
            b_logprobs = self.logprobs.reshape(-1)
            b_actions = self.actions.reshape(-1)
            b_ext_advantages = ext_advantages.reshape(-1)
            b_ext_returns = ext_returns.reshape(-1)

            b_advantages = b_ext_advantages * self.args.ext_coef

            # Optimizing the policy and value network
            b_inds = np.arange(self.args.batch_size)

            clipfracs = []
            for epoch in range(self.args.update_epochs):
                np.random.shuffle(b_inds)
                for start in range(0, self.args.batch_size, self.args.minibatch_size):
                    end = start + self.args.minibatch_size
                    mb_inds = b_inds[start:end]

                    _, newlogprob, entropy, new_ext_values, _ = self.agent.get_action_and_value(
                        b_obs[mb_inds], b_actions.long()[mb_inds]
                    )
                    logratio = newlogprob - b_logprobs[mb_inds]
                    ratio = logratio.exp()

                    with torch.no_grad():
                        # calculate approx_kl http://joschu.net/blog/kl-approx.html
                        old_approx_kl = (-logratio).mean()
                        approx_kl = ((ratio - 1) - logratio).mean()
                        clipfracs += [((ratio - 1.0).abs() > self.args.clip_coef).float().mean().item()]

                    mb_advantages = b_advantages[mb_inds]
                    if self.args.norm_adv:
                        mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

                    # Policy loss
                    pg_loss = self.compute_policy_loss(mb_advantages, ratio)

                    # Value loss
                    v_loss = self.compute_value_loss(new_ext_values, b_ext_returns[mb_inds])

                    # Entropy loss
                    entropy_loss = entropy.mean()
                    loss = pg_loss - self.args.ent_coef * entropy_loss + v_loss * self.args.vf_coef

                    self.optimizer.zero_grad()
                    loss.backward()
                    if self.args.max_grad_norm:
                        nn.utils.clip_grad_norm_(
                            self.combined_parameters,
                            self.args.max_grad_norm,
                        )
                    self.optimizer.step()

                if self.args.target_kl is not None:
                    if approx_kl > self.args.target_kl:
                        break

            # record rewards for plotting purposes
            self.writer.add_scalar("charts/learning_rate", self.optimizer.param_groups[0]["lr"], global_step)
            self.writer.add_scalar("losses/value_loss", v_loss.item(), global_step)
            self.writer.add_scalar("losses/policy_loss", pg_loss.item(), global_step)
            self.writer.add_scalar("losses/entropy", entropy_loss.item(), global_step)
            self.tlol.plot_ppo_loss(entropy_loss.item(), global_step)
            self.writer.add_scalar("losses/old_approx_kl", old_approx_kl.item(), global_step)
            self.writer.add_scalar("losses/approx_kl", approx_kl.item(), global_step)
            # print("SPS:", int(global_step / (time.time() - start_time))) # Uncomment if you want to estimate your training speed - should be around 50 and the beginning and 200+ later steps per second on Colab
            self.tlol.plot_ppo_sps(int(global_step / (time.time() - start_time)), global_step)
            self.writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)

# %%
args = Args(
    num_steps=32,
    num_workers=8,
    num_envs=128,
    env_id="MiniHack-KeyRoom-S5-v0",
    total_timesteps=1_000_000,
)

# %%
args.batch_size = int(args.num_envs * args.num_steps)
args.minibatch_size = int(args.batch_size // args.num_minibatches)
args.num_iterations = args.total_timesteps // args.batch_size
run_name = f"{args.env_id}__ppo__{args.seed}__{int(time.time())}"

writer = SummaryWriter(f"runs/{run_name}")
writer.add_text(
    "hyperparameters",
    "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
)

# seeding
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = args.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")
env = create_env(args)

agent = Agent(env).to(device)

trainer = PPOTrainer(args, writer, env, agent, tlol)
trainer.train()

env.close()
writer.close()

play(agent, args)
Video("trajectory.mp4", embed=True)
# Out:
# local_step=25483, 20_avg_episodic_return=0.6000000238418579
# local_step=25506, 20_avg_episodic_return=0.0
# local_step=25528, 20_avg_episodic_return=0.0
# local_step=25549, 20_avg_episodic_return=0.0
# local_step=25573, 20_avg_episodic_return=0.0
# local_step=25597, 20_avg_episodic_return=0.0
# local_step=44745, 20_avg_episodic_return=0.6000000238418579
# local_step=51217, 20_avg_episodic_return=0.15000000596046448
# local_step=51245, 20_avg_episodic_return=0.0
# local_step=51267, 20_avg_episodic_return=0.0
# local_step=51294, 20_avg_episodic_return=0.0
# local_step=51319, 20_avg_episodic_return=0.0
# local_step=65574, 20_avg_episodic_return=0.550000011920929
# local_step=74364, 20_avg_episodic_return=0.3499999940395355
# local_step=76959, 20_avg_episodic_return=0.10000000149011612
# local_step=76987, 20_avg_episodic_return=0.0
# local_step=77018, 20_avg_episodic_return=0.0
# local_step=77045, 20_avg_episodic_return=0.0
# local_step=86409, 20_avg_episodic_return=0.4000000059604645
# local_step=92990, 20_avg_episodic_return=0.44999998807907104
# local_step=100337, 20_avg_episodic_return=0.44999998807907104
# local_step=102690, 20_avg_episodic_return=0.0
# local_step=102723, 20_avg_episodic_return=0.0
# local_step=102758, 20_avg_episodic_return=0.0
# local_step=108009, 20_avg_episodic_return=0.25
# local_step=113302, 20_avg_episodic_return=0.5
# local_step=119050, 20_avg_episodic_return=0.20000000298023224
# local_step=126352, 20_avg_episodic_return=0.30000001192092896
# local_step=128426, 20_avg_episodic_return=0.05000000074505806
# local_step=128466, 20_avg_episodic_return=0.0
# local_step=129914, 20_avg_episodic_return=0.05000000074505806
# local_step=136494, 20_avg_episodic_return=0.3499999940395355
# local_step=141012, 20_avg_episodic_return=0.15000000596046448
# local_step=146964, 20_avg_episodic_return=0.10000000149011612
# local_step=153394, 20_avg_episodic_return=0.30000001192092896
# local_step=154172, 20_avg_episodic_return=0.0
# local_step=154221, 20_avg_episodic_return=0.05000000074505806
# local_step=159671, 20_avg_episodic_return=0.15000000596046448
# local_step=163362, 20_avg_episodic_return=0.4000000059604645
# local_step=168447, 20_avg_episodic_return=0.15000000596046448
# local_step=173821, 20_avg_episodic_return=0.3499999940395355
# local_step=178702, 20_avg_episodic_return=0.25
# local_step=179903, 20_avg_episodic_return=0.05000000074505806
# local_step=181547, 20_avg_episodic_return=0.10000000149011612
# local_step=187205, 20_avg_episodic_return=0.20000000298023224
# local_step=190486, 20_avg_episodic_return=0.25
# local_step=194121, 20_avg_episodic_return=0.3499999940395355
# local_step=197921, 20_avg_episodic_return=0.30000001192092896
# local_step=203536, 20_avg_episodic_return=0.25
# local_step=205619, 20_avg_episodic_return=0.10000000149011612
# local_step=207592, 20_avg_episodic_return=0.15000000596046448
# local_step=213020, 20_avg_episodic_return=0.25
# local_step=217037, 20_avg_episodic_return=0.15000000596046448
# local_step=220928, 20_avg_episodic_return=0.20000000298023224
# local_step=224877, 20_avg_episodic_return=0.20000000298023224
# local_step=229727, 20_avg_episodic_return=0.3499999940395355
# local_step=231376, 20_avg_episodic_return=0.0
# local_step=235044, 20_avg_episodic_return=0.3499999940395355
# local_step=237493, 20_avg_episodic_return=0.3499999940395355
# local_step=242059, 20_avg_episodic_return=0.3499999940395355
# local_step=245631, 20_avg_episodic_return=0.30000001192092896
# local_step=249152, 20_avg_episodic_return=0.44999998807907104
# local_step=254055, 20_avg_episodic_return=0.5
# local_step=257025, 20_avg_episodic_return=0.44999998807907104
# local_step=258554, 20_avg_episodic_return=0.05000000074505806
# local_step=262640, 20_avg_episodic_return=0.4000000059604645
# local_step=264862, 20_avg_episodic_return=0.3499999940395355
# local_step=269353, 20_avg_episodic_return=0.550000011920929
# local_step=272185, 20_avg_episodic_return=0.550000011920929
# local_step=276532, 20_avg_episodic_return=0.44999998807907104
# local_step=280227, 20_avg_episodic_return=0.4000000059604645
# local_step=282767, 20_avg_episodic_return=0.3499999940395355
# local_step=286384, 20_avg_episodic_return=0.25
# local_step=288882, 20_avg_episodic_return=0.4000000059604645
# local_step=291853, 20_avg_episodic_return=0.44999998807907104
# local_step=295141, 20_avg_episodic_return=0.5
# local_step=297726, 20_avg_episodic_return=0.44999998807907104
# local_step=301432, 20_avg_episodic_return=0.44999998807907104
# local_step=304369, 20_avg_episodic_return=0.550000011920929
# local_step=307203, 20_avg_episodic_return=0.44999998807907104
# local_step=310010, 20_avg_episodic_return=0.44999998807907104
# local_step=313525, 20_avg_episodic_return=0.6000000238418579
# local_step=316522, 20_avg_episodic_return=0.5
# local_step=320809, 20_avg_episodic_return=0.4000000059604645
# local_step=323430, 20_avg_episodic_return=0.3499999940395355
# local_step=326821, 20_avg_episodic_return=0.550000011920929
# local_step=329828, 20_avg_episodic_return=0.30000001192092896
# local_step=332931, 20_avg_episodic_return=0.3499999940395355
# local_step=335565, 20_avg_episodic_return=0.4000000059604645
# local_step=339218, 20_avg_episodic_return=0.3499999940395355
# local_step=342250, 20_avg_episodic_return=0.3499999940395355
# local_step=345461, 20_avg_episodic_return=0.6000000238418579
# local_step=348030, 20_avg_episodic_return=0.6000000238418579
# local_step=350856, 20_avg_episodic_return=0.3499999940395355
# local_step=354275, 20_avg_episodic_return=0.44999998807907104
# local_step=357777, 20_avg_episodic_return=0.44999998807907104
# local_step=360055, 20_avg_episodic_return=0.30000001192092896
# local_step=363472, 20_avg_episodic_return=0.550000011920929
# local_step=365839, 20_avg_episodic_return=0.44999998807907104
# local_step=368892, 20_avg_episodic_return=0.44999998807907104
# local_step=372265, 20_avg_episodic_return=0.3499999940395355
# local_step=376014, 20_avg_episodic_return=0.3499999940395355
# local_step=379105, 20_avg_episodic_return=0.44999998807907104
# local_step=382169, 20_avg_episodic_return=0.6499999761581421
# local_step=383990, 20_avg_episodic_return=0.44999998807907104
# local_step=386725, 20_avg_episodic_return=0.6000000238418579
# local_step=389315, 20_avg_episodic_return=0.550000011920929
# local_step=391632, 20_avg_episodic_return=0.699999988079071
# local_step=394365, 20_avg_episodic_return=0.3499999940395355
# local_step=396365, 20_avg_episodic_return=0.44999998807907104
# local_step=399009, 20_avg_episodic_return=0.75
# local_step=401222, 20_avg_episodic_return=0.75
# local_step=403426, 20_avg_episodic_return=0.550000011920929
# local_step=405249, 20_avg_episodic_return=0.6499999761581421
# local_step=408564, 20_avg_episodic_return=0.6499999761581421
# local_step=410611, 20_avg_episodic_return=0.550000011920929
# local_step=413199, 20_avg_episodic_return=0.75
# local_step=415191, 20_avg_episodic_return=0.949999988079071
# local_step=418717, 20_avg_episodic_return=0.6000000238418579
# local_step=421205, 20_avg_episodic_return=0.44999998807907104
# local_step=423376, 20_avg_episodic_return=0.8500000238418579
# local_step=425364, 20_avg_episodic_return=0.800000011920929
# local_step=427923, 20_avg_episodic_return=0.5
# local_step=429989, 20_avg_episodic_return=0.6499999761581421
# local_step=431639, 20_avg_episodic_return=0.550000011920929
# local_step=433455, 20_avg_episodic_return=0.800000011920929
# local_step=435474, 20_avg_episodic_return=0.75
# local_step=437134, 20_avg_episodic_return=0.8500000238418579
# local_step=438877, 20_avg_episodic_return=0.75
# local_step=440690, 20_avg_episodic_return=0.800000011920929
# local_step=443082, 20_avg_episodic_return=0.949999988079071
# local_step=444809, 20_avg_episodic_return=0.8500000238418579
# local_step=446448, 20_avg_episodic_return=0.949999988079071
# local_step=448172, 20_avg_episodic_return=0.699999988079071
# local_step=450221, 20_avg_episodic_return=0.8500000238418579
# local_step=451581, 20_avg_episodic_return=0.8500000238418579
# local_step=453876, 20_avg_episodic_return=0.8999999761581421
# local_step=455431, 20_avg_episodic_return=0.8999999761581421
# local_step=456578, 20_avg_episodic_return=0.8999999761581421
# local_step=459194, 20_avg_episodic_return=0.800000011920929
# local_step=461299, 20_avg_episodic_return=0.8500000238418579
# local_step=462862, 20_avg_episodic_return=0.949999988079071
# local_step=464838, 20_avg_episodic_return=0.800000011920929
# local_step=466782, 20_avg_episodic_return=0.8500000238418579
# local_step=468237, 20_avg_episodic_return=0.8999999761581421
# local_step=469784, 20_avg_episodic_return=0.8500000238418579
# local_step=471514, 20_avg_episodic_return=0.949999988079071
# local_step=473253, 20_avg_episodic_return=0.8500000238418579
# local_step=474830, 20_avg_episodic_return=1.0
# local_step=476340, 20_avg_episodic_return=1.0
# local_step=477737, 20_avg_episodic_return=0.8500000238418579
# local_step=479327, 20_avg_episodic_return=0.949999988079071
# local_step=480942, 20_avg_episodic_return=0.8999999761581421
# local_step=482074, 20_avg_episodic_return=0.75
# local_step=483944, 20_avg_episodic_return=0.8999999761581421
# local_step=485861, 20_avg_episodic_return=0.75
# local_step=487484, 20_avg_episodic_return=0.75
# local_step=488756, 20_avg_episodic_return=0.8500000238418579
# local_step=490404, 20_avg_episodic_return=0.8999999761581421
# local_step=492080, 20_avg_episodic_return=0.8500000238418579
# local_step=493280, 20_avg_episodic_return=0.8500000238418579
# local_step=494912, 20_avg_episodic_return=1.0
# local_step=496605, 20_avg_episodic_return=1.0
# local_step=498836, 20_avg_episodic_return=0.8999999761581421
# local_step=500403, 20_avg_episodic_return=0.699999988079071
# local_step=501573, 20_avg_episodic_return=0.800000011920929
# local_step=503242, 20_avg_episodic_return=0.800000011920929
# local_step=504354, 20_avg_episodic_return=0.949999988079071
# local_step=505754, 20_avg_episodic_return=0.949999988079071
# local_step=506595, 20_avg_episodic_return=0.8999999761581421
# local_step=508253, 20_avg_episodic_return=0.8999999761581421
# local_step=509938, 20_avg_episodic_return=0.8500000238418579
# local_step=511037, 20_avg_episodic_return=1.0
# local_step=513347, 20_avg_episodic_return=1.0
# local_step=514705, 20_avg_episodic_return=0.8999999761581421
# local_step=516032, 20_avg_episodic_return=0.949999988079071
# local_step=517067, 20_avg_episodic_return=0.949999988079071
# local_step=518631, 20_avg_episodic_return=0.8999999761581421
# local_step=520056, 20_avg_episodic_return=0.949999988079071
# local_step=521596, 20_avg_episodic_return=0.949999988079071
# local_step=523251, 20_avg_episodic_return=0.949999988079071
# local_step=524323, 20_avg_episodic_return=0.949999988079071
# local_step=526382, 20_avg_episodic_return=0.949999988079071
# local_step=528379, 20_avg_episodic_return=0.949999988079071
# local_step=530232, 20_avg_episodic_return=0.949999988079071
# local_step=531509, 20_avg_episodic_return=0.949999988079071
# local_step=532998, 20_avg_episodic_return=0.8500000238418579
# local_step=534218, 20_avg_episodic_return=0.949999988079071
# local_step=535409, 20_avg_episodic_return=0.949999988079071
# local_step=537088, 20_avg_episodic_return=0.8999999761581421
# local_step=538876, 20_avg_episodic_return=0.8999999761581421
# local_step=540489, 20_avg_episodic_return=0.8500000238418579
# local_step=542344, 20_avg_episodic_return=0.8999999761581421
# local_step=543622, 20_avg_episodic_return=0.800000011920929
# local_step=545538, 20_avg_episodic_return=0.949999988079071
# local_step=547140, 20_avg_episodic_return=0.8500000238418579
# local_step=548952, 20_avg_episodic_return=0.8500000238418579
# local_step=550066, 20_avg_episodic_return=0.75
# local_step=551713, 20_avg_episodic_return=0.8500000238418579
# local_step=553269, 20_avg_episodic_return=0.949999988079071
# local_step=554791, 20_avg_episodic_return=0.8999999761581421
# local_step=556441, 20_avg_episodic_return=1.0
# local_step=557588, 20_avg_episodic_return=0.8500000238418579
# local_step=559424, 20_avg_episodic_return=0.949999988079071
# local_step=561277, 20_avg_episodic_return=0.800000011920929
# local_step=562233, 20_avg_episodic_return=0.8999999761581421
# local_step=563263, 20_avg_episodic_return=0.8999999761581421
# local_step=564596, 20_avg_episodic_return=0.8999999761581421
# local_step=565946, 20_avg_episodic_return=1.0
# local_step=566846, 20_avg_episodic_return=0.800000011920929
# local_step=568199, 20_avg_episodic_return=0.8999999761581421
# local_step=569759, 20_avg_episodic_return=1.0
# local_step=571072, 20_avg_episodic_return=0.949999988079071
# local_step=572070, 20_avg_episodic_return=0.949999988079071
# local_step=573539, 20_avg_episodic_return=1.0
# local_step=575071, 20_avg_episodic_return=0.949999988079071
# local_step=575860, 20_avg_episodic_return=0.8999999761581421
# local_step=577153, 20_avg_episodic_return=0.949999988079071
# local_step=578298, 20_avg_episodic_return=1.0
# local_step=579249, 20_avg_episodic_return=0.800000011920929
# local_step=580351, 20_avg_episodic_return=1.0
# local_step=581605, 20_avg_episodic_return=0.8999999761581421
# local_step=582834, 20_avg_episodic_return=0.949999988079071
# local_step=583880, 20_avg_episodic_return=0.8999999761581421
# local_step=585037, 20_avg_episodic_return=1.0
# local_step=586461, 20_avg_episodic_return=1.0
# local_step=587856, 20_avg_episodic_return=1.0
# local_step=589222, 20_avg_episodic_return=1.0
# local_step=590790, 20_avg_episodic_return=0.949999988079071
# local_step=591667, 20_avg_episodic_return=0.949999988079071
# local_step=592689, 20_avg_episodic_return=1.0
# local_step=593741, 20_avg_episodic_return=1.0
# local_step=594525, 20_avg_episodic_return=1.0
# local_step=595590, 20_avg_episodic_return=0.8999999761581421
# local_step=596757, 20_avg_episodic_return=1.0
# local_step=597865, 20_avg_episodic_return=0.949999988079071
# local_step=598836, 20_avg_episodic_return=1.0
# local_step=599752, 20_avg_episodic_return=1.0
# local_step=600685, 20_avg_episodic_return=0.949999988079071
# local_step=601717, 20_avg_episodic_return=1.0
# local_step=602804, 20_avg_episodic_return=0.949999988079071
# local_step=604269, 20_avg_episodic_return=0.949999988079071
# local_step=605448, 20_avg_episodic_return=0.949999988079071
# local_step=606428, 20_avg_episodic_return=1.0
# local_step=607491, 20_avg_episodic_return=1.0
# local_step=608378, 20_avg_episodic_return=1.0
# local_step=609493, 20_avg_episodic_return=0.949999988079071
# local_step=610578, 20_avg_episodic_return=0.949999988079071
# local_step=611655, 20_avg_episodic_return=1.0
# local_step=613349, 20_avg_episodic_return=0.949999988079071
# local_step=614073, 20_avg_episodic_return=0.949999988079071
# local_step=615136, 20_avg_episodic_return=0.949999988079071
# local_step=616241, 20_avg_episodic_return=1.0
# local_step=617456, 20_avg_episodic_return=1.0
# local_step=618322, 20_avg_episodic_return=1.0
# local_step=619626, 20_avg_episodic_return=0.949999988079071
# local_step=620553, 20_avg_episodic_return=1.0
# local_step=621750, 20_avg_episodic_return=1.0
# local_step=623349, 20_avg_episodic_return=0.8500000238418579
# local_step=624152, 20_avg_episodic_return=0.8999999761581421
# local_step=625073, 20_avg_episodic_return=0.949999988079071
# local_step=625984, 20_avg_episodic_return=0.8500000238418579
# local_step=626800, 20_avg_episodic_return=0.949999988079071
# local_step=628009, 20_avg_episodic_return=1.0
# local_step=629110, 20_avg_episodic_return=0.949999988079071
# local_step=629867, 20_avg_episodic_return=0.949999988079071
# local_step=630811, 20_avg_episodic_return=0.949999988079071
# local_step=631765, 20_avg_episodic_return=1.0
# local_step=632607, 20_avg_episodic_return=1.0
# local_step=633236, 20_avg_episodic_return=1.0
# local_step=634345, 20_avg_episodic_return=1.0
# local_step=635227, 20_avg_episodic_return=1.0
# local_step=636023, 20_avg_episodic_return=1.0
# local_step=636841, 20_avg_episodic_return=0.949999988079071
# local_step=637804, 20_avg_episodic_return=1.0
# local_step=639127, 20_avg_episodic_return=1.0
# local_step=640086, 20_avg_episodic_return=1.0
# local_step=641041, 20_avg_episodic_return=1.0
# local_step=641870, 20_avg_episodic_return=1.0
# local_step=643154, 20_avg_episodic_return=0.949999988079071
# local_step=644183, 20_avg_episodic_return=1.0
# local_step=645114, 20_avg_episodic_return=1.0
# local_step=645887, 20_avg_episodic_return=1.0
# local_step=646817, 20_avg_episodic_return=1.0
# local_step=647687, 20_avg_episodic_return=0.949999988079071
# local_step=648377, 20_avg_episodic_return=1.0
# local_step=649135, 20_avg_episodic_return=1.0
# local_step=649580, 20_avg_episodic_return=1.0
# local_step=650366, 20_avg_episodic_return=1.0
# local_step=651344, 20_avg_episodic_return=0.8999999761581421
# local_step=652244, 20_avg_episodic_return=1.0
# local_step=653122, 20_avg_episodic_return=0.949999988079071
# local_step=653876, 20_avg_episodic_return=1.0
# local_step=654575, 20_avg_episodic_return=1.0
# local_step=655779, 20_avg_episodic_return=1.0
# local_step=656719, 20_avg_episodic_return=1.0
# local_step=657758, 20_avg_episodic_return=1.0
# local_step=658684, 20_avg_episodic_return=1.0
# local_step=659341, 20_avg_episodic_return=1.0
# local_step=660122, 20_avg_episodic_return=1.0
# local_step=661010, 20_avg_episodic_return=1.0
# local_step=661920, 20_avg_episodic_return=1.0
# local_step=662582, 20_avg_episodic_return=0.949999988079071
# local_step=663315, 20_avg_episodic_return=1.0
# local_step=664066, 20_avg_episodic_return=1.0
# local_step=665018, 20_avg_episodic_return=1.0
# local_step=665783, 20_avg_episodic_return=1.0
# local_step=666410, 20_avg_episodic_return=1.0
# local_step=667353, 20_avg_episodic_return=1.0
# local_step=667852, 20_avg_episodic_return=1.0
# local_step=668689, 20_avg_episodic_return=1.0
# local_step=669692, 20_avg_episodic_return=1.0
# local_step=670389, 20_avg_episodic_return=1.0
# local_step=671025, 20_avg_episodic_return=1.0
# local_step=671933, 20_avg_episodic_return=1.0
# local_step=672587, 20_avg_episodic_return=1.0
# local_step=673583, 20_avg_episodic_return=1.0
# local_step=674202, 20_avg_episodic_return=1.0
# local_step=674830, 20_avg_episodic_return=1.0
# local_step=675572, 20_avg_episodic_return=1.0
# local_step=676513, 20_avg_episodic_return=1.0
# local_step=677210, 20_avg_episodic_return=1.0
# local_step=677806, 20_avg_episodic_return=1.0
# local_step=678567, 20_avg_episodic_return=1.0
# local_step=679423, 20_avg_episodic_return=1.0
# local_step=680379, 20_avg_episodic_return=1.0
# local_step=681104, 20_avg_episodic_return=1.0
# local_step=681544, 20_avg_episodic_return=1.0
# local_step=682281, 20_avg_episodic_return=1.0
# local_step=682812, 20_avg_episodic_return=1.0
# local_step=683516, 20_avg_episodic_return=1.0
# local_step=684171, 20_avg_episodic_return=1.0
# local_step=685260, 20_avg_episodic_return=0.949999988079071
# local_step=685920, 20_avg_episodic_return=1.0
# local_step=686376, 20_avg_episodic_return=1.0
# local_step=687269, 20_avg_episodic_return=1.0
# local_step=687849, 20_avg_episodic_return=0.949999988079071
# local_step=688453, 20_avg_episodic_return=1.0
# local_step=689103, 20_avg_episodic_return=1.0
# local_step=689922, 20_avg_episodic_return=1.0
# local_step=690587, 20_avg_episodic_return=1.0
# local_step=691535, 20_avg_episodic_return=1.0
# local_step=692314, 20_avg_episodic_return=1.0
# local_step=693086, 20_avg_episodic_return=1.0
# local_step=693587, 20_avg_episodic_return=1.0
# local_step=694335, 20_avg_episodic_return=1.0
# local_step=695238, 20_avg_episodic_return=1.0
# local_step=696040, 20_avg_episodic_return=1.0
# local_step=696558, 20_avg_episodic_return=1.0
# local_step=697500, 20_avg_episodic_return=1.0
# local_step=698304, 20_avg_episodic_return=1.0
# local_step=698888, 20_avg_episodic_return=1.0
# local_step=700028, 20_avg_episodic_return=1.0
# local_step=700632, 20_avg_episodic_return=1.0
# local_step=701536, 20_avg_episodic_return=1.0
# local_step=702157, 20_avg_episodic_return=1.0
# local_step=702660, 20_avg_episodic_return=1.0
# local_step=703564, 20_avg_episodic_return=1.0
# local_step=704205, 20_avg_episodic_return=1.0
# local_step=704895, 20_avg_episodic_return=1.0
# local_step=705868, 20_avg_episodic_return=1.0
# local_step=706727, 20_avg_episodic_return=1.0
# local_step=707168, 20_avg_episodic_return=0.949999988079071
# local_step=707927, 20_avg_episodic_return=1.0
# local_step=708948, 20_avg_episodic_return=1.0
# local_step=709665, 20_avg_episodic_return=1.0
# local_step=710142, 20_avg_episodic_return=1.0
# local_step=710975, 20_avg_episodic_return=1.0
# local_step=711601, 20_avg_episodic_return=1.0
# local_step=712214, 20_avg_episodic_return=1.0
# local_step=713036, 20_avg_episodic_return=1.0
# local_step=713645, 20_avg_episodic_return=1.0
# local_step=714326, 20_avg_episodic_return=1.0
# local_step=714782, 20_avg_episodic_return=1.0
# local_step=715626, 20_avg_episodic_return=1.0
# local_step=716129, 20_avg_episodic_return=1.0
# local_step=717242, 20_avg_episodic_return=1.0
# local_step=717848, 20_avg_episodic_return=1.0
# local_step=718682, 20_avg_episodic_return=1.0
# local_step=719466, 20_avg_episodic_return=1.0
# local_step=720095, 20_avg_episodic_return=1.0
# local_step=720864, 20_avg_episodic_return=1.0
# local_step=721463, 20_avg_episodic_return=1.0
# local_step=722230, 20_avg_episodic_return=1.0
# local_step=722946, 20_avg_episodic_return=1.0
# local_step=723759, 20_avg_episodic_return=1.0
# local_step=724402, 20_avg_episodic_return=1.0
# local_step=725012, 20_avg_episodic_return=0.949999988079071
# local_step=725773, 20_avg_episodic_return=1.0
# local_step=726478, 20_avg_episodic_return=0.949999988079071
# local_step=727135, 20_avg_episodic_return=1.0
# local_step=727731, 20_avg_episodic_return=1.0
# local_step=728187, 20_avg_episodic_return=1.0
# local_step=728933, 20_avg_episodic_return=1.0
# local_step=729698, 20_avg_episodic_return=1.0
# local_step=730357, 20_avg_episodic_return=1.0
# local_step=731223, 20_avg_episodic_return=1.0
# local_step=731885, 20_avg_episodic_return=1.0
# local_step=732533, 20_avg_episodic_return=1.0
# local_step=733322, 20_avg_episodic_return=1.0
# local_step=733952, 20_avg_episodic_return=1.0
# local_step=734622, 20_avg_episodic_return=1.0
# local_step=735170, 20_avg_episodic_return=1.0
# local_step=735803, 20_avg_episodic_return=1.0
# local_step=736784, 20_avg_episodic_return=0.949999988079071
# local_step=737406, 20_avg_episodic_return=1.0
# local_step=737968, 20_avg_episodic_return=1.0
# local_step=738556, 20_avg_episodic_return=1.0
# local_step=739425, 20_avg_episodic_return=1.0
# local_step=740497, 20_avg_episodic_return=1.0
# local_step=741149, 20_avg_episodic_return=1.0
# local_step=741760, 20_avg_episodic_return=1.0
# local_step=742524, 20_avg_episodic_return=1.0
# local_step=743052, 20_avg_episodic_return=1.0
# local_step=743892, 20_avg_episodic_return=1.0
# local_step=744616, 20_avg_episodic_return=1.0
# local_step=745070, 20_avg_episodic_return=1.0
# local_step=745912, 20_avg_episodic_return=1.0
# local_step=746562, 20_avg_episodic_return=1.0
# local_step=747142, 20_avg_episodic_return=1.0
# local_step=747704, 20_avg_episodic_return=1.0
# local_step=748452, 20_avg_episodic_return=1.0
# local_step=749057, 20_avg_episodic_return=1.0
# local_step=749880, 20_avg_episodic_return=1.0
# local_step=750280, 20_avg_episodic_return=1.0
# local_step=750973, 20_avg_episodic_return=1.0
# local_step=751686, 20_avg_episodic_return=1.0
# local_step=752608, 20_avg_episodic_return=0.949999988079071
# local_step=753221, 20_avg_episodic_return=1.0
# local_step=753827, 20_avg_episodic_return=1.0
# local_step=754537, 20_avg_episodic_return=1.0
# local_step=755508, 20_avg_episodic_return=1.0
# local_step=756067, 20_avg_episodic_return=1.0
# local_step=756621, 20_avg_episodic_return=1.0
# local_step=757301, 20_avg_episodic_return=1.0
# local_step=757856, 20_avg_episodic_return=1.0
# local_step=758556, 20_avg_episodic_return=1.0
# local_step=759181, 20_avg_episodic_return=1.0
# local_step=759765, 20_avg_episodic_return=1.0
# local_step=760626, 20_avg_episodic_return=1.0
# local_step=761384, 20_avg_episodic_return=1.0
# local_step=762008, 20_avg_episodic_return=1.0
# local_step=762713, 20_avg_episodic_return=1.0
# local_step=763149, 20_avg_episodic_return=0.949999988079071
# local_step=763825, 20_avg_episodic_return=1.0
# local_step=764422, 20_avg_episodic_return=1.0
# local_step=765132, 20_avg_episodic_return=1.0
# local_step=765832, 20_avg_episodic_return=1.0
# local_step=766606, 20_avg_episodic_return=1.0
# local_step=767120, 20_avg_episodic_return=1.0
# local_step=767820, 20_avg_episodic_return=1.0
# local_step=768326, 20_avg_episodic_return=1.0
# local_step=768851, 20_avg_episodic_return=1.0
# local_step=769968, 20_avg_episodic_return=1.0
# local_step=770638, 20_avg_episodic_return=1.0
# local_step=771238, 20_avg_episodic_return=1.0
# local_step=771718, 20_avg_episodic_return=1.0
# local_step=772440, 20_avg_episodic_return=1.0
# local_step=772922, 20_avg_episodic_return=1.0
# local_step=773548, 20_avg_episodic_return=1.0
# local_step=774030, 20_avg_episodic_return=1.0
# local_step=774758, 20_avg_episodic_return=1.0
# local_step=775337, 20_avg_episodic_return=1.0
# local_step=775946, 20_avg_episodic_return=1.0
# local_step=776628, 20_avg_episodic_return=1.0
# local_step=777200, 20_avg_episodic_return=1.0
# local_step=777812, 20_avg_episodic_return=1.0
# local_step=778516, 20_avg_episodic_return=1.0
# local_step=779171, 20_avg_episodic_return=1.0
# local_step=779692, 20_avg_episodic_return=1.0
# local_step=780329, 20_avg_episodic_return=1.0
# local_step=780833, 20_avg_episodic_return=1.0
# local_step=781660, 20_avg_episodic_return=1.0
# local_step=782357, 20_avg_episodic_return=1.0
# local_step=782861, 20_avg_episodic_return=1.0
# local_step=783576, 20_avg_episodic_return=1.0
# local_step=784008, 20_avg_episodic_return=1.0
# local_step=784773, 20_avg_episodic_return=1.0
# local_step=785387, 20_avg_episodic_return=1.0
# local_step=785952, 20_avg_episodic_return=1.0
# local_step=786516, 20_avg_episodic_return=1.0
# local_step=787154, 20_avg_episodic_return=1.0
# local_step=787586, 20_avg_episodic_return=1.0
# local_step=788257, 20_avg_episodic_return=1.0
# local_step=788899, 20_avg_episodic_return=1.0
# local_step=789462, 20_avg_episodic_return=1.0
# local_step=790067, 20_avg_episodic_return=1.0
# local_step=790901, 20_avg_episodic_return=1.0
# local_step=791521, 20_avg_episodic_return=1.0
# local_step=792213, 20_avg_episodic_return=1.0
# local_step=792735, 20_avg_episodic_return=1.0
# local_step=793274, 20_avg_episodic_return=1.0
# local_step=793966, 20_avg_episodic_return=1.0
# local_step=794770, 20_avg_episodic_return=1.0
# local_step=795374, 20_avg_episodic_return=1.0
# local_step=795838, 20_avg_episodic_return=1.0
# local_step=796614, 20_avg_episodic_return=1.0
# local_step=797226, 20_avg_episodic_return=1.0
# local_step=798038, 20_avg_episodic_return=1.0
# local_step=798456, 20_avg_episodic_return=1.0
# local_step=799291, 20_avg_episodic_return=1.0
# local_step=799815, 20_avg_episodic_return=1.0
# local_step=800424, 20_avg_episodic_return=1.0
# local_step=800997, 20_avg_episodic_return=1.0
# local_step=801462, 20_avg_episodic_return=1.0
# local_step=802064, 20_avg_episodic_return=1.0
# local_step=803070, 20_avg_episodic_return=1.0
# local_step=803600, 20_avg_episodic_return=1.0
# local_step=804196, 20_avg_episodic_return=1.0
# local_step=804683, 20_avg_episodic_return=1.0
# local_step=805436, 20_avg_episodic_return=1.0
# local_step=806072, 20_avg_episodic_return=1.0
# local_step=806677, 20_avg_episodic_return=1.0
# local_step=807053, 20_avg_episodic_return=1.0
# local_step=807680, 20_avg_episodic_return=1.0
# local_step=808343, 20_avg_episodic_return=1.0
# local_step=808853, 20_avg_episodic_return=1.0
# local_step=809472, 20_avg_episodic_return=1.0
# local_step=810078, 20_avg_episodic_return=1.0
# local_step=810771, 20_avg_episodic_return=1.0
# local_step=811334, 20_avg_episodic_return=1.0
# local_step=811888, 20_avg_episodic_return=1.0
# local_step=812499, 20_avg_episodic_return=1.0
# local_step=813160, 20_avg_episodic_return=1.0
# local_step=813659, 20_avg_episodic_return=1.0
# local_step=814270, 20_avg_episodic_return=1.0
# local_step=814808, 20_avg_episodic_return=1.0
# local_step=815214, 20_avg_episodic_return=1.0
# local_step=815885, 20_avg_episodic_return=1.0
# local_step=816331, 20_avg_episodic_return=1.0
# local_step=817086, 20_avg_episodic_return=0.949999988079071
# local_step=817711, 20_avg_episodic_return=1.0
# local_step=818183, 20_avg_episodic_return=1.0
# local_step=818597, 20_avg_episodic_return=1.0
# local_step=819409, 20_avg_episodic_return=1.0
# local_step=819856, 20_avg_episodic_return=1.0
# local_step=820632, 20_avg_episodic_return=1.0
# local_step=821058, 20_avg_episodic_return=1.0
# local_step=821732, 20_avg_episodic_return=1.0
# local_step=822248, 20_avg_episodic_return=1.0
# local_step=822962, 20_avg_episodic_return=1.0
# local_step=823654, 20_avg_episodic_return=1.0
# local_step=824153, 20_avg_episodic_return=1.0
# local_step=824545, 20_avg_episodic_return=1.0
# local_step=825214, 20_avg_episodic_return=1.0
# local_step=825656, 20_avg_episodic_return=0.949999988079071
# local_step=826131, 20_avg_episodic_return=1.0
# local_step=827049, 20_avg_episodic_return=1.0
# local_step=827464, 20_avg_episodic_return=1.0
# local_step=828006, 20_avg_episodic_return=1.0
# local_step=828575, 20_avg_episodic_return=1.0
# local_step=829186, 20_avg_episodic_return=1.0
# local_step=829598, 20_avg_episodic_return=1.0
# local_step=830193, 20_avg_episodic_return=1.0
# local_step=830811, 20_avg_episodic_return=1.0
# local_step=831287, 20_avg_episodic_return=1.0
# local_step=831781, 20_avg_episodic_return=1.0
# local_step=832158, 20_avg_episodic_return=1.0
# local_step=832881, 20_avg_episodic_return=1.0
# local_step=833569, 20_avg_episodic_return=1.0
# local_step=834187, 20_avg_episodic_return=1.0
# local_step=835012, 20_avg_episodic_return=1.0
# local_step=835431, 20_avg_episodic_return=0.949999988079071
# local_step=835987, 20_avg_episodic_return=1.0
# local_step=836593, 20_avg_episodic_return=1.0
# local_step=837018, 20_avg_episodic_return=1.0
# local_step=837444, 20_avg_episodic_return=1.0
# local_step=838320, 20_avg_episodic_return=1.0
# local_step=838945, 20_avg_episodic_return=1.0
# local_step=839489, 20_avg_episodic_return=1.0
# local_step=840117, 20_avg_episodic_return=1.0
# local_step=840695, 20_avg_episodic_return=1.0
# local_step=841275, 20_avg_episodic_return=1.0
# local_step=841786, 20_avg_episodic_return=1.0
# local_step=842241, 20_avg_episodic_return=1.0
# local_step=842720, 20_avg_episodic_return=1.0
# local_step=843130, 20_avg_episodic_return=1.0
# local_step=844047, 20_avg_episodic_return=1.0
# local_step=844610, 20_avg_episodic_return=0.949999988079071
# local_step=845148, 20_avg_episodic_return=1.0
# local_step=845611, 20_avg_episodic_return=1.0
# local_step=845997, 20_avg_episodic_return=1.0
# local_step=846612, 20_avg_episodic_return=1.0
# local_step=847135, 20_avg_episodic_return=1.0
# local_step=847723, 20_avg_episodic_return=1.0
# local_step=848352, 20_avg_episodic_return=1.0
# local_step=848902, 20_avg_episodic_return=1.0
# local_step=849704, 20_avg_episodic_return=1.0
# local_step=850368, 20_avg_episodic_return=1.0
# local_step=850821, 20_avg_episodic_return=1.0
# local_step=851324, 20_avg_episodic_return=1.0
# local_step=851971, 20_avg_episodic_return=1.0
# local_step=852640, 20_avg_episodic_return=1.0
# local_step=853168, 20_avg_episodic_return=1.0
# local_step=853731, 20_avg_episodic_return=1.0
# local_step=854230, 20_avg_episodic_return=1.0
# local_step=854796, 20_avg_episodic_return=1.0
# local_step=855387, 20_avg_episodic_return=1.0
# local_step=855881, 20_avg_episodic_return=1.0
# local_step=856461, 20_avg_episodic_return=1.0
# local_step=856984, 20_avg_episodic_return=1.0
# local_step=857518, 20_avg_episodic_return=1.0
# local_step=857894, 20_avg_episodic_return=1.0
# local_step=858365, 20_avg_episodic_return=1.0
# local_step=858807, 20_avg_episodic_return=1.0
# local_step=859357, 20_avg_episodic_return=1.0
# local_step=859939, 20_avg_episodic_return=1.0
# local_step=860408, 20_avg_episodic_return=1.0
# local_step=860918, 20_avg_episodic_return=1.0
# local_step=861366, 20_avg_episodic_return=1.0
# local_step=861980, 20_avg_episodic_return=1.0
# local_step=862777, 20_avg_episodic_return=1.0
# local_step=863237, 20_avg_episodic_return=1.0
# local_step=863704, 20_avg_episodic_return=1.0
# local_step=864317, 20_avg_episodic_return=1.0
# local_step=864677, 20_avg_episodic_return=1.0
# local_step=865458, 20_avg_episodic_return=1.0
# local_step=865940, 20_avg_episodic_return=1.0
# local_step=866436, 20_avg_episodic_return=1.0
# local_step=867014, 20_avg_episodic_return=1.0
# local_step=867382, 20_avg_episodic_return=1.0
# local_step=868032, 20_avg_episodic_return=1.0
# local_step=868611, 20_avg_episodic_return=1.0
# local_step=869068, 20_avg_episodic_return=1.0
# local_step=869558, 20_avg_episodic_return=1.0
# local_step=870078, 20_avg_episodic_return=1.0
# local_step=870732, 20_avg_episodic_return=1.0
# local_step=871292, 20_avg_episodic_return=1.0
# local_step=871939, 20_avg_episodic_return=1.0
# local_step=872349, 20_avg_episodic_return=1.0
# local_step=872817, 20_avg_episodic_return=1.0
# local_step=873558, 20_avg_episodic_return=1.0
# local_step=874018, 20_avg_episodic_return=1.0
# local_step=874639, 20_avg_episodic_return=1.0
# local_step=875021, 20_avg_episodic_return=1.0
# local_step=875531, 20_avg_episodic_return=1.0
# local_step=876237, 20_avg_episodic_return=1.0
# local_step=876739, 20_avg_episodic_return=1.0
# local_step=877290, 20_avg_episodic_return=1.0
# local_step=877754, 20_avg_episodic_return=1.0
# local_step=878307, 20_avg_episodic_return=1.0
# local_step=878968, 20_avg_episodic_return=1.0
# local_step=879349, 20_avg_episodic_return=1.0
# local_step=879855, 20_avg_episodic_return=1.0
# local_step=880619, 20_avg_episodic_return=1.0
# local_step=880992, 20_avg_episodic_return=1.0
# local_step=881485, 20_avg_episodic_return=1.0
# local_step=882146, 20_avg_episodic_return=1.0
# local_step=882600, 20_avg_episodic_return=1.0
# local_step=883011, 20_avg_episodic_return=1.0
# local_step=883725, 20_avg_episodic_return=1.0
# local_step=884211, 20_avg_episodic_return=1.0
# local_step=884709, 20_avg_episodic_return=1.0
# local_step=885379, 20_avg_episodic_return=1.0
# local_step=885840, 20_avg_episodic_return=1.0
# local_step=886361, 20_avg_episodic_return=1.0
# local_step=886730, 20_avg_episodic_return=1.0
# local_step=887286, 20_avg_episodic_return=1.0
# local_step=887902, 20_avg_episodic_return=1.0
# local_step=888349, 20_avg_episodic_return=1.0
# local_step=889058, 20_avg_episodic_return=1.0
# local_step=889439, 20_avg_episodic_return=1.0
# local_step=889933, 20_avg_episodic_return=1.0
# local_step=890476, 20_avg_episodic_return=1.0
# local_step=891224, 20_avg_episodic_return=1.0
# local_step=891724, 20_avg_episodic_return=1.0
# local_step=892335, 20_avg_episodic_return=1.0
# local_step=892723, 20_avg_episodic_return=1.0
# local_step=893276, 20_avg_episodic_return=1.0
# local_step=893659, 20_avg_episodic_return=1.0
# local_step=894235, 20_avg_episodic_return=1.0
# local_step=894801, 20_avg_episodic_return=1.0
# local_step=895144, 20_avg_episodic_return=1.0
# local_step=895804, 20_avg_episodic_return=1.0
# local_step=896206, 20_avg_episodic_return=1.0
# local_step=896695, 20_avg_episodic_return=1.0
# local_step=897277, 20_avg_episodic_return=1.0
# local_step=897825, 20_avg_episodic_return=1.0
# local_step=898288, 20_avg_episodic_return=1.0
# local_step=898774, 20_avg_episodic_return=1.0
# local_step=899387, 20_avg_episodic_return=1.0
# local_step=899864, 20_avg_episodic_return=0.949999988079071
# local_step=900389, 20_avg_episodic_return=1.0
# local_step=900781, 20_avg_episodic_return=1.0
# local_step=901482, 20_avg_episodic_return=1.0
# local_step=901917, 20_avg_episodic_return=1.0
# local_step=902318, 20_avg_episodic_return=1.0
# local_step=902891, 20_avg_episodic_return=1.0
# local_step=903257, 20_avg_episodic_return=1.0
# local_step=903956, 20_avg_episodic_return=1.0
# local_step=904440, 20_avg_episodic_return=1.0
# local_step=905294, 20_avg_episodic_return=1.0
# local_step=905581, 20_avg_episodic_return=1.0
# local_step=906410, 20_avg_episodic_return=1.0
# local_step=906976, 20_avg_episodic_return=1.0
# local_step=907512, 20_avg_episodic_return=1.0
# local_step=907889, 20_avg_episodic_return=1.0
# local_step=908342, 20_avg_episodic_return=1.0
# local_step=909047, 20_avg_episodic_return=1.0
# local_step=909583, 20_avg_episodic_return=1.0
# local_step=909948, 20_avg_episodic_return=1.0
# local_step=910302, 20_avg_episodic_return=1.0
# local_step=910934, 20_avg_episodic_return=1.0
# local_step=911337, 20_avg_episodic_return=1.0
# local_step=911823, 20_avg_episodic_return=1.0
# local_step=912364, 20_avg_episodic_return=1.0
# local_step=912759, 20_avg_episodic_return=1.0
# local_step=913181, 20_avg_episodic_return=1.0
# local_step=913797, 20_avg_episodic_return=1.0
# local_step=914264, 20_avg_episodic_return=1.0
# local_step=914824, 20_avg_episodic_return=1.0
# local_step=915322, 20_avg_episodic_return=1.0
# local_step=915715, 20_avg_episodic_return=1.0
# local_step=916086, 20_avg_episodic_return=1.0
# local_step=916507, 20_avg_episodic_return=1.0
# local_step=916951, 20_avg_episodic_return=1.0
# local_step=917832, 20_avg_episodic_return=1.0
# local_step=918140, 20_avg_episodic_return=1.0
# local_step=918512, 20_avg_episodic_return=1.0
# local_step=918977, 20_avg_episodic_return=1.0
# local_step=919627, 20_avg_episodic_return=1.0
# local_step=920191, 20_avg_episodic_return=1.0
# local_step=920614, 20_avg_episodic_return=1.0
# local_step=921132, 20_avg_episodic_return=1.0
# local_step=921582, 20_avg_episodic_return=1.0
# local_step=922043, 20_avg_episodic_return=1.0
# local_step=922590, 20_avg_episodic_return=1.0
# local_step=922926, 20_avg_episodic_return=1.0
# local_step=923551, 20_avg_episodic_return=1.0
# local_step=924127, 20_avg_episodic_return=1.0
# local_step=924624, 20_avg_episodic_return=1.0
# local_step=925055, 20_avg_episodic_return=1.0
# local_step=925500, 20_avg_episodic_return=1.0
# local_step=925867, 20_avg_episodic_return=1.0
# local_step=926572, 20_avg_episodic_return=1.0
# local_step=926933, 20_avg_episodic_return=1.0
# local_step=927500, 20_avg_episodic_return=1.0
# local_step=928126, 20_avg_episodic_return=1.0
# local_step=928575, 20_avg_episodic_return=1.0
# local_step=929058, 20_avg_episodic_return=1.0
# local_step=929578, 20_avg_episodic_return=1.0
# local_step=930140, 20_avg_episodic_return=1.0
# local_step=930564, 20_avg_episodic_return=1.0
# local_step=930932, 20_avg_episodic_return=1.0
# local_step=931358, 20_avg_episodic_return=1.0
# local_step=932015, 20_avg_episodic_return=1.0
# local_step=932470, 20_avg_episodic_return=1.0
# local_step=933047, 20_avg_episodic_return=1.0
# local_step=933532, 20_avg_episodic_return=1.0
# local_step=934054, 20_avg_episodic_return=1.0
# local_step=934462, 20_avg_episodic_return=1.0
# local_step=934903, 20_avg_episodic_return=1.0
# local_step=935369, 20_avg_episodic_return=1.0
# local_step=935890, 20_avg_episodic_return=1.0
# local_step=936520, 20_avg_episodic_return=1.0
# local_step=936933, 20_avg_episodic_return=1.0
# local_step=937562, 20_avg_episodic_return=1.0
# local_step=937998, 20_avg_episodic_return=1.0
# local_step=938500, 20_avg_episodic_return=1.0
# local_step=939005, 20_avg_episodic_return=1.0
# local_step=939479, 20_avg_episodic_return=1.0
# local_step=939866, 20_avg_episodic_return=1.0
# local_step=940249, 20_avg_episodic_return=1.0
# local_step=940695, 20_avg_episodic_return=1.0
# local_step=941173, 20_avg_episodic_return=1.0
# local_step=941776, 20_avg_episodic_return=1.0
# local_step=942211, 20_avg_episodic_return=1.0
# local_step=942853, 20_avg_episodic_return=1.0
# local_step=943431, 20_avg_episodic_return=1.0
# local_step=943814, 20_avg_episodic_return=1.0
# local_step=944346, 20_avg_episodic_return=1.0
# local_step=944923, 20_avg_episodic_return=1.0
# local_step=945463, 20_avg_episodic_return=1.0
# local_step=945984, 20_avg_episodic_return=1.0
# local_step=946421, 20_avg_episodic_return=1.0
# local_step=946935, 20_avg_episodic_return=1.0
# local_step=947572, 20_avg_episodic_return=1.0
# local_step=948177, 20_avg_episodic_return=1.0
# local_step=948671, 20_avg_episodic_return=1.0
# local_step=949124, 20_avg_episodic_return=1.0
# local_step=949548, 20_avg_episodic_return=1.0
# local_step=949938, 20_avg_episodic_return=1.0
# local_step=950400, 20_avg_episodic_return=1.0
# local_step=950895, 20_avg_episodic_return=1.0
# local_step=951606, 20_avg_episodic_return=1.0
# local_step=952079, 20_avg_episodic_return=1.0
# local_step=952622, 20_avg_episodic_return=1.0
# local_step=952970, 20_avg_episodic_return=1.0
# local_step=953494, 20_avg_episodic_return=1.0
# local_step=954086, 20_avg_episodic_return=1.0
# local_step=954592, 20_avg_episodic_return=1.0
# local_step=955003, 20_avg_episodic_return=1.0
# local_step=955451, 20_avg_episodic_return=1.0
# local_step=955926, 20_avg_episodic_return=1.0
# local_step=956433, 20_avg_episodic_return=1.0
# local_step=956947, 20_avg_episodic_return=1.0
# local_step=957367, 20_avg_episodic_return=1.0
# local_step=957871, 20_avg_episodic_return=1.0
# local_step=958406, 20_avg_episodic_return=1.0
# local_step=958965, 20_avg_episodic_return=1.0
# local_step=959411, 20_avg_episodic_return=1.0
# local_step=959828, 20_avg_episodic_return=1.0
# local_step=960362, 20_avg_episodic_return=1.0
# local_step=960898, 20_avg_episodic_return=1.0
# local_step=961239, 20_avg_episodic_return=1.0
# local_step=961668, 20_avg_episodic_return=1.0
# local_step=962257, 20_avg_episodic_return=1.0
# local_step=962749, 20_avg_episodic_return=1.0
# local_step=963187, 20_avg_episodic_return=1.0
# local_step=963671, 20_avg_episodic_return=1.0
# local_step=964123, 20_avg_episodic_return=1.0
# local_step=964649, 20_avg_episodic_return=1.0
# local_step=965132, 20_avg_episodic_return=1.0
# local_step=965734, 20_avg_episodic_return=1.0
# local_step=966032, 20_avg_episodic_return=1.0
# local_step=966577, 20_avg_episodic_return=1.0
# local_step=966999, 20_avg_episodic_return=1.0
# local_step=967539, 20_avg_episodic_return=1.0
# local_step=967926, 20_avg_episodic_return=1.0
# local_step=968302, 20_avg_episodic_return=1.0
# local_step=968978, 20_avg_episodic_return=1.0
# local_step=969322, 20_avg_episodic_return=1.0
# local_step=969762, 20_avg_episodic_return=1.0
# local_step=970323, 20_avg_episodic_return=1.0
# local_step=970857, 20_avg_episodic_return=1.0
# local_step=971269, 20_avg_episodic_return=1.0
# local_step=971733, 20_avg_episodic_return=1.0
# local_step=972219, 20_avg_episodic_return=1.0
# local_step=972830, 20_avg_episodic_return=1.0
# local_step=973227, 20_avg_episodic_return=1.0
# local_step=973814, 20_avg_episodic_return=1.0
# local_step=974314, 20_avg_episodic_return=1.0
# local_step=974805, 20_avg_episodic_return=1.0
# local_step=975242, 20_avg_episodic_return=1.0
# local_step=975704, 20_avg_episodic_return=1.0
# local_step=976193, 20_avg_episodic_return=1.0
# local_step=976774, 20_avg_episodic_return=1.0
# local_step=977201, 20_avg_episodic_return=1.0
# local_step=977766, 20_avg_episodic_return=1.0
# local_step=978319, 20_avg_episodic_return=1.0
# local_step=978613, 20_avg_episodic_return=1.0
# local_step=979229, 20_avg_episodic_return=1.0
# local_step=979685, 20_avg_episodic_return=1.0
# local_step=980082, 20_avg_episodic_return=1.0
# local_step=980656, 20_avg_episodic_return=1.0
# local_step=981363, 20_avg_episodic_return=1.0
# local_step=981766, 20_avg_episodic_return=1.0
# local_step=982129, 20_avg_episodic_return=1.0
# local_step=982505, 20_avg_episodic_return=1.0
# local_step=983238, 20_avg_episodic_return=1.0
# local_step=983942, 20_avg_episodic_return=1.0
# local_step=984298, 20_avg_episodic_return=1.0
# local_step=984681, 20_avg_episodic_return=1.0
# local_step=985294, 20_avg_episodic_return=1.0
# local_step=985805, 20_avg_episodic_return=1.0
# local_step=986131, 20_avg_episodic_return=1.0
# local_step=986640, 20_avg_episodic_return=1.0
# local_step=987182, 20_avg_episodic_return=1.0
# local_step=987739, 20_avg_episodic_return=1.0
# local_step=988147, 20_avg_episodic_return=1.0
# local_step=988645, 20_avg_episodic_return=1.0
# local_step=989187, 20_avg_episodic_return=1.0
# local_step=989535, 20_avg_episodic_return=1.0
# local_step=990022, 20_avg_episodic_return=1.0
# local_step=990482, 20_avg_episodic_return=1.0
# local_step=991097, 20_avg_episodic_return=1.0
# local_step=991512, 20_avg_episodic_return=1.0
# local_step=992035, 20_avg_episodic_return=1.0
# local_step=992673, 20_avg_episodic_return=1.0
# local_step=993087, 20_avg_episodic_return=1.0
# local_step=993465, 20_avg_episodic_return=1.0
# local_step=993970, 20_avg_episodic_return=1.0
# local_step=994390, 20_avg_episodic_return=1.0
# local_step=994798, 20_avg_episodic_return=1.0
# local_step=995324, 20_avg_episodic_return=1.0
# local_step=995788, 20_avg_episodic_return=1.0
# local_step=996288, 20_avg_episodic_return=1.0
# local_step=996868, 20_avg_episodic_return=1.0
# local_step=997185, 20_avg_episodic_return=1.0
# local_step=997701, 20_avg_episodic_return=1.0
# local_step=998155, 20_avg_episodic_return=1.0
# local_step=998705, 20_avg_episodic_return=1.0
# local_step=999197, 20_avg_episodic_return=1.0
# /home/nojak/.pyenv/versions/3.10.16/envs/venv-rltask/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning:
#
# WARN: env.gym_env to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.gym_env` for environment variables or `env.get_wrapper_attr('gym_env')` that will search the reminding wrappers.
#
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 430) to (608, 432) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# reward: 1.0, steps: 22
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ### PPO should be able to solve this environment in 1M env steps

# %% [markdown]
# # Task 2: Random Network Distillation

# %% [markdown]
# ## Motivation behind Random Network Distillation
#
# Exploitation versus exploration is a critical topic in Reinforcement Learning. We'd like the RL agent to find the best solution as fast as possible. However, in the meantime, committing to solutions too quickly without enough exploration sounds pretty bad, as it could lead to local minima or total failure. Modern RL algorithms that optimize for the best returns can achieve good exploitation quite efficiently, while exploration remains more like an open topic.
#
# ### Classic exploration strategies
#
# As a quick recap, let's first go through several classic exploration algorithms.
# - Epsilon-greedy: The agent does random exploration occasionally with probability and takes the optimal action most of the time with probability ($1 - \epsilon$).
# - Entropy loss term: Add an entropy term $H(\pi(a|s))$ into the loss function, encouraging the policy to take diverse actions.
#
# ### The Hard Exploration problem
#
# The “hard-exploration” problem refers to exploration in an environment with very sparse or even deceptive rewards. It is difficult because random exploration in such scenarios can rarely discover successful states or obtain meaningful feedback.
#
# [Montezuma's Revenge](https://en.wikipedia.org/wiki/Montezuma%27s_Revenge_(video_game)) is a concrete example of the hard-exploration problem. It is one of a few challenging games in Atari for DRL to solve. Many papers use Montezuma's Revenge to benchmark their results.
#
# ### Intrinsic Rewards as Exploration Bonuses
# One common approach to better exploration, especially for solving the hard-exploration problem, is to augment the environment reward with an additional bonus signal to encourage extra exploration. The policy is thus trained with a reward composed of two terms $r_t = r_t^e + \beta r_t^i$, where $\beta$ is a hyperparameter adjusting the balance between exploitation and exploration.
#
# - $r_t^e$ is an extrinsic reward from the environment at time $t$, defined according to the task in hand.
# - $r_t^i$ is an intrinsic exploration bonus at time $t$.
#
# This intrinsic reward is somewhat inspired by intrinsic motivation in psychology (Oudeyer & Kaplan, 2008). Exploration driven by curiosity might be an important way for children to grow and learn. In other words, exploratory activities should be rewarding intrinsically in the human mind to encourage such behavior. The intrinsic rewards could be correlated with curiosity, surprise, familiarity with the state, and many other factors.
#
# ### Prediction based exploration
# In this homework, we will focus on intrinsic exploration bonuses rewarded for the improvement of the agent's knowledge about the environment. The agent's familiarity with the environment dynamics can be estimated through a prediction model. This idea of using a prediction model to measure curiosity was actually proposed quite a long time ago (Schmidhuber, 1991).
#
# Specifically, we will implement Random Network Distillation (RND; Burda, et al. 2018) which introduces a prediction task <i>independent</i> of the main task. The RND exploration bonus is defined as the error of a neural network $\hat{f}(s_t)$ predicting features of the observations given by a <i>fixed randomly initialized</i> neural network $f(s_t)$. The motivation is that given a new state, if similar states have been visited many times in the past, the prediction should be easier and thus have lower error. The exploration bonus is
# $r_i = |\hat{f}(s_t; \theta) - f(s_t)|_2^2$
#
# ![img](https://drive.google.com/uc?export=view&id=1WB_T4kHtaE-oJWR-NedX0Mw-I1It4F31)
#
# Two factors are important in RND experiments:
#
# 1. Non-episodic setting results in better exploration, especially when not using any extrinsic rewards. It means that the return is not truncated at “Game over” and intrinsic return can spread across multiple episodes.
# 2. Normalization is important since the scale of the reward is tricky to adjust given a random neural network as a prediction target. The intrinsic reward is normalized by division by a running estimate of the standard deviations of the intrinsic return.
#
# The RND setup works well for resolving the hard-exploration problem. For example, maximizing the RND exploration bonus consistently finds more than half of the rooms in Montezuma's Revenge.

# %% [markdown]
# ## Implement RND model class
#
# For this task, you need to implement a Random Network Distillation (RND) model, the backbone of curiosity-driven exploration. The model consists of two main components - `target` and `predictor` that <b>should not have shared components</b>! You can use a similar approach for encoding observation as in the Agent. The predictor network is trainable and tries to predict the outputs of the target network, which remains fixed (non-trainable).

# %%
class RNDModel(nn.Module):
    def __init__(self, env):
        super().__init__()

        self.dtype = pufferlib.pytorch.nativize_dtype(env.emulated)

        # Predictor Network
        self.predictor_blstats_net = nn.Sequential(
            nn.Embedding(256, 32),
            nn.Flatten(),
        )

        self.predictor_char_embed = nn.Embedding(256, 32)
        self.predictor_chars_net = nn.Sequential(
            layer_init(nn.Conv2d(32, 32, 5, stride=(2, 3))),
            nn.ReLU(),
            layer_init(nn.Conv2d(32, 64, 5, stride=(1, 3))),
            nn.ReLU(),
            layer_init(nn.Conv2d(64, 64, 3, stride=1)),
            nn.ReLU(),
            nn.Flatten(),
        )

        self.predictor_proj = nn.Linear(864+960, 256)
        self.predictor = nn.Sequential(
            layer_init(nn.Linear(256, 512)),
            nn.ReLU(),
            layer_init(nn.Linear(512, 512)),
            nn.ReLU(),
            layer_init(nn.Linear(512, 512)),
        )

        # Target Network
        self.target_blstats_net = nn.Sequential(
            nn.Embedding(256, 32),
            nn.Flatten(),
        )

        self.target_char_embed = nn.Embedding(256, 32)
        self.target_chars_net = nn.Sequential(
            layer_init(nn.Conv2d(32, 32, 5, stride=(2, 3))),
            nn.ReLU(),
            layer_init(nn.Conv2d(32, 64, 5, stride=(1, 3))),
            nn.ReLU(),
            layer_init(nn.Conv2d(64, 64, 3, stride=1)),
            nn.ReLU(),
            nn.Flatten(),
        )

        self.target_proj = nn.Linear(864+960, 256)
        self.target = nn.Sequential(
            layer_init(nn.Linear(256, 512)),
        )

        # target network is not trainable
        for name, param in self.named_parameters():
            if name.startswith('target'):
                param.requires_grad = False

    def encode_predictor(self, x):
        x = x.type(torch.uint8)  # Undo bad cleanrl cast
        x = pufferlib.pytorch.nativize_tensor(x, self.dtype)

        blstats = torch.clip(x['blstats'] + 1, 0, 255).int()
        blstats = self.predictor_blstats_net(blstats)

        chars = self.predictor_char_embed(x['chars'].int())
        chars = torch.permute(chars, (0, 3, 1, 2))
        chars = self.predictor_chars_net(chars)

        concat = torch.cat([blstats, chars], dim=1)
        return self.predictor_proj(concat)

    def encode_target(self, x):
        x = x.type(torch.uint8)  # Undo bad cleanrl cast
        x = pufferlib.pytorch.nativize_tensor(x, self.dtype)

        blstats = torch.clip(x['blstats'] + 1, 0, 255).int()
        blstats = self.target_blstats_net(blstats)

        chars = self.target_char_embed(x['chars'].int())
        chars = torch.permute(chars, (0, 3, 1, 2))
        chars = self.target_chars_net(chars)

        concat = torch.cat([blstats, chars], dim=1)
        return self.target_proj(concat)

    def forward(self, next_obs):
        """
        Encode observations with `encode_predictor` and `encode_target`.
        Infer `predictor` and `target` networks to return their predictions.
        """
        ### BEGIN SOLUTION - RND forward

        predict_feature = self.predictor(self.encode_predictor(next_obs))

        target_feature = self.target(self.encode_target(next_obs))

        ### END SOLUTION
        return predict_feature, target_feature

# %% [markdown]
# ## RND Trainer

# %%
class RNDTrainer(PPOTrainer):
    def __init__(self, args, writer, env, agent, rnd_model, tlol):
        super().__init__(args, writer, env, agent, tlol)
        self.rnd_model = rnd_model
        self.curiosity_rewards = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)
        self.int_values = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)

        self.combined_parameters = list(self.agent.parameters()) + list(self.rnd_model.predictor.parameters())
        self.optimizer = optim.Adam(
            self.combined_parameters,
            lr=self.args.learning_rate,
            eps=1e-5,
        )

    def calculate_curiosity_rewards(self, step, next_obs):
        """
        Your task is to implement the computation of curiosity-driven rewards.
        Curiosity rewards are used to encourage the agent to explore novel states by quantifying the prediction error
        of a Random Network Distillation (RND) model. The larger the prediction error, the more novel the state is
        considered, and the higher the reward.

        Available Variables:
        - `self.obs_rms.mean` (np.Array): The running mean of observations.
        - `self.obs_rms.var` (np.Array): The running variance of observations.
        - `self.rnd_model(obs)`: A method that takes an observation as input and returns two outputs:
            1. `predict_next_feature`: The output of the predictor network.
            2. `target_next_feature`: The output of the fixed target network.
        - `self.curiosity_rewards`: A tensor where curiosity rewards for each timestep are stored.

        Implementation Details:
        - Normalize `next_obs` using running mean (`self.obs_rms.mean`) and variance (`self.obs_rms.var`).
        Clip normalized values to a range of [-5, 5] for numerical stability.
        - Pass the normalized observation (`rnd_next_obs`) through the RND model to obtain `predict_next_feature`
        and `target_next_feature`.
        - Compute curiosity reward as half of the squared L2 norm of the difference between
        `target_next_feature` and `predict_next_feature`.
        - Store the computed reward in `self.curiosity_rewards[step]` as a tensor on the `self.device`.
        - Other components of the `steps_curiosity_rewards` have to be casted to tensors and put on the `self.device` 
        """
        ### BEGIN SOLUTION - RNDT calculate_curiosity_rewards

        def cast_and_put(x, device):
            x = torch.from_numpy(x).to(device)
            return x

        mean = cast_and_put(self.obs_rms.mean, self.device)
        var = cast_and_put(self.obs_rms.var, self.device)

        next_obs.to(self.device)
        next_obs = (next_obs - mean) / var 

        next_obs = torch.clip(next_obs, -5, 5)

        predict_next_feature, target_next_feature = self.rnd_model(next_obs)

        steps_curiosity_rewards = (1/2) * torch.sum((predict_next_feature.data - target_next_feature.data) ** 2, dim = 1)

        ### END SOLUTION
        self.curiosity_rewards[step] = steps_curiosity_rewards


    def compute_int_advantages(self, next_obs):
        """
        Your task is to implement the computation of advantages specifically for intrinsic rewards using Generalized Advantage Estimation (GAE).
        This method is similar to `compute_advantages`, which you have already seen, but it focuses on intrinsic rewards instead of extrinsic rewards.

        Available Variables:
        - `self.curiosity_rewards`: A tensor containing intrinsic rewards for each timestep in the trajectory.
        - `self.int_values`: A tensor containing value estimates for intrinsic rewards at each timestep.
        - `self.agent.get_value(obs)`: A method that returns value estimates; the second output corresponds to intrinsic values.
        - `self.args.int_gamma`: The discount factor for intrinsic rewards.
        - `self.args.gae_lambda`: The GAE lambda parameter.

        Notes: 
        - Intrinsic rewards do not depend on terminal states
        - Solution will be very similar to `PPOTrainer.compute_advantages` with variables from the `self.RNDTrainer` 
        """


        with torch.no_grad():
            ### BEGIN SOLUTION - RNDT compute_int_advantages

            _, next_value_int = self.agent.get_value(next_obs)
            next_value_int = next_value_int.reshape(1, -1)

            int_advantages = torch.zeros_like(self.curiosity_rewards, device=self.device)
            int_lastgaelam = 0

            for t in reversed(range(self.args.num_steps)):
                if t == self.args.num_steps - 1:
                    int_nextvalues = next_value_int
                else:
                    int_nextvalues = self.int_values[t + 1]

                int_delta = (self.curiosity_rewards[t] + self.args.int_gamma * int_nextvalues - self.int_values[t])
                int_advantages[t] = int_lastgaelam = (int_delta + self.args.int_gamma * self.args.gae_lambda * int_lastgaelam)

            ### END SOLUTION
        return int_advantages

    def compute_rnd_loss(self, rnd_next_obs):
        """
        Your task is to implement the computation of the RND loss.

        Available Variables and Methods:
        - `self.rnd_model(obs)`: A method that takes an observation as input and returns two outputs:
            1. `predict_next_state_feature`: The output of the predictor network.
            2. `target_next_state_feature`: The output of the fixed target network.
        - `F.mse_loss`: A PyTorch function to compute mean squared error.
        - `self.args.update_proportion`: A float value indicating the proportion of samples to use for updating.
        - `self.device`: The device (CPU or GPU) on which computations are performed.

        Implementation Details:
        - Compute the forward loss as the mean squared error between `predict_next_state_feature` and `target_next_state_feature`.
        Ensure that gradients are not computed for the target network by detaching it.
        - Create a random mask to select a subset of samples based on `self.args.update_proportion`.
        Use this mask to filter which samples contribute to the loss.
        - Normalize the loss by dividing by the sum of masked elements, ensuring numerical stability by handling cases where
        no elements are selected.
        """

        ### BEGIN SOLUTION - RNDT compute_rnd_loss

        predict_next_state_feature, target_next_state_feature = self.rnd_model(rnd_next_obs) 

        forward_loss = torch.nn.functional.mse_loss(
            predict_next_state_feature,
            target_next_state_feature.detach(),
            reduction = 'none',
        )
        forward_loss.to(self.device)
        forward_loss = torch.mean(forward_loss, dim = 1)

        mask = torch.full_like(forward_loss, self.args.update_proportion)
        mask.to(self.device)
        mask = torch.distributions.Bernoulli(probs = mask).sample()

        mask_sums = torch.sum(mask)
        mask_sums.to(self.device)

        ones = torch.ones_like(mask_sums)
        ones.to(self.device)
        mask_sums = torch.stack([mask_sums, ones])
        mask_sums = torch.max(mask_sums, dim = 0).values.view(-1, 1)

        forward_loss = torch.sum(forward_loss * mask) / mask_sums

        ### END SOLUTION
        return forward_loss

    def train(self):
        # ALGO Logic: Storage setup
        avg_returns = deque(maxlen=self.av_er_interval)
        avg_curiosity_reward = deque(maxlen=self.av_er_interval)

        # start the game
        global_step = 0
        start_time = time.time()
        next_obs = torch.Tensor(self.env.reset()[0]).to(self.device)
        next_done = torch.zeros(self.args.num_envs).to(self.device)
        next_time_out = torch.zeros(self.args.num_envs).to(self.device)
        num_updates = self.args.total_timesteps // self.args.batch_size

        reward_rms = RunningMeanStd()
        self.obs_rms = RunningMeanStd(shape=(1,) + self.env.single_observation_space.shape)
        discounted_reward = RewardForwardFilter(self.args.int_gamma)

        print("Start to initialize observation normalization parameter.....")
        next_ob = []
        for step in range(self.args.num_steps * self.args.num_iterations_obs_norm_init):
            acs = np.random.randint(0, self.env.single_action_space.n, size=(self.args.num_envs,))
            o, r, te, tr, _ = self.env.step(acs)
            next_ob += o.tolist()

            if len(next_ob) % (self.args.num_steps * self.args.num_envs) == 0:
                next_ob = np.stack(next_ob)
                self.obs_rms.update(next_ob)
                next_ob = []
        print("End to initialize...")

        for update in range(1, num_updates + 1):
            # Annealing the rate if instructed to do so.
            if self.args.anneal_lr:
                frac = 1.0 - (update - 1.0) / num_updates
                lrnow = frac * self.args.learning_rate
                self.optimizer.param_groups[0]["lr"] = lrnow

            for step in range(0, self.args.num_steps):
                global_step += 1 * self.args.num_envs
                self.obs[step] = next_obs
                self.dones[step] = next_done
                self.time_outs[step] = next_time_out

                # ALGO LOGIC: action logic
                with torch.no_grad():
                    value_ext, value_int = self.agent.get_value(self.obs[step])
                    self.ext_values[step], self.int_values[step] = (
                        value_ext.flatten(),
                        value_int.flatten(),
                    )
                    action, logprob, _, _, _ = self.agent.get_action_and_value(self.obs[step])

                self.actions[step] = action
                self.logprobs[step] = logprob

                # execute the game and log data.
                next_obs, reward, terminated, truncated, info = self.env.step(action.cpu().numpy())
                self.rewards[step] = torch.tensor(reward).to(self.device).view(-1)
                next_obs = torch.Tensor(next_obs).to(self.device)
                next_done = torch.Tensor(terminated).to(self.device)
                next_time_out = torch.Tensor(truncated).to(self.device)

                self.calculate_curiosity_rewards(step, next_obs)
                local_step = global_step - 1 * self.args.num_envs
                for idx, d in enumerate(terminated | truncated):
                    local_step+=1
                    if d:
                        avg_returns.append(info["r"][idx])
                        avg_curiosity_reward.append(np.mean(self.curiosity_rewards[step].cpu().numpy()))
                        epi_ret = np.average(avg_returns)
                        epi_cr = np.average(avg_curiosity_reward)
                        epi_suc = np.average([1 if r > 0 else 0 for r in avg_returns])
                        if self.er_counter >= self.av_er_interval:
                            self.er_counter = 0
                            print(
                                f"step={local_step}, {self.av_er_interval}_avg_episodic_return={epi_ret}, curiosity_reward={epi_cr}"
                            )
                            tlol.plot_rnd_er(epi_ret, epi_cr, local_step)
                        else:
                            self.er_counter += 1

                        self.writer.add_scalar("charts/avg_success_rate", epi_suc, local_step)
                        self.writer.add_scalar("charts/avg_episodic_return", epi_ret, local_step)
                        self.writer.add_scalar("charts/episodic_return", info["r"][idx], local_step)
                        self.writer.add_scalar(
                            "charts/episode_curiosity_reward",
                            self.curiosity_rewards[step][idx],
                            local_step,
                        )
                        self.writer.add_scalar("charts/episodic_length", info["l"][idx], local_step)

            curiosity_reward_per_env = np.array(
                [discounted_reward.update(reward_per_step) for reward_per_step in self.curiosity_rewards.cpu().data.numpy().T]
            )
            mean, std, count = (
                np.mean(curiosity_reward_per_env),
                np.std(curiosity_reward_per_env),
                len(curiosity_reward_per_env),
            )
            reward_rms.update_from_moments(mean, std**2, count)

            self.curiosity_rewards /= np.sqrt(reward_rms.var)

            if self.args.value_bootstrap:
                # Value bootstrapping is a technique that reduces the surprise for the critic in case
                # we're ending the episode by timeout. Intuitively, in this case the cumulative return for the last step
                # should not be zero, but rather what the critic expects. This improves learning in many envs
                # because otherwise the critic cannot predict the abrupt change in rewards in a timed-out episode.
                # What we really want here is v(t+1) which we don't have because we don't have obs(t+1) (since
                # the episode ended). Using v(t) is an approximation that requires that rew(t) can be generally ignored.
                self.rewards.add_(self.args.gamma * self.ext_values * self.time_outs)
                self.curiosity_rewards.add_(self.args.int_gamma * self.int_values * self.time_outs)

            # bootstrap value if not done
            with torch.no_grad():
                ext_advantages = self.compute_advantages(next_obs, next_done)
                int_advantages = self.compute_int_advantages(next_obs)
                ext_returns = ext_advantages + self.ext_values
                int_returns = int_advantages + self.int_values

            # flatten the batch
            b_obs = self.obs.reshape((-1,) + self.env.single_observation_space.shape)
            b_logprobs = self.logprobs.reshape(-1)
            b_actions = self.actions.reshape(-1)
            b_ext_advantages = ext_advantages.reshape(-1)
            b_int_advantages = int_advantages.reshape(-1)
            b_ext_returns = ext_returns.reshape(-1)
            b_int_returns = int_returns.reshape(-1)
            b_ext_values = self.ext_values.reshape(-1)

            b_advantages = b_int_advantages * self.args.int_coef + b_ext_advantages * self.args.ext_coef

            self.obs_rms.update(b_obs.cpu().numpy())

            # Optimizing the policy and value network
            b_inds = np.arange(self.args.batch_size)

            rnd_next_obs = (
                (
                    (b_obs - torch.from_numpy(self.obs_rms.mean).to(self.device))
                    / torch.sqrt(torch.from_numpy(self.obs_rms.var).to(self.device))
                ).clip(-5, 5)
            ).float()

            clipfracs = []
            for epoch in range(self.args.update_epochs):
                np.random.shuffle(b_inds)
                for start in range(0, self.args.batch_size, self.args.minibatch_size):
                    end = start + self.args.minibatch_size
                    mb_inds = b_inds[start:end]

                    # Forward loss
                    forward_loss = self.compute_rnd_loss(rnd_next_obs[mb_inds])

                    _, newlogprob, entropy, new_ext_values, new_int_values = self.agent.get_action_and_value(
                        b_obs[mb_inds], b_actions.long()[mb_inds]
                    )
                    logratio = newlogprob - b_logprobs[mb_inds]
                    ratio = logratio.exp()

                    with torch.no_grad():
                        # calculate approx_kl http://joschu.net/blog/kl-approx.html
                        old_approx_kl = (-logratio).mean()
                        approx_kl = ((ratio - 1) - logratio).mean()
                        clipfracs += [((ratio - 1.0).abs() > self.args.clip_coef).float().mean().item()]

                    mb_advantages = b_advantages[mb_inds]
                    if self.args.norm_adv:
                        mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

                    # Policy loss
                    pg_loss = self.compute_policy_loss(mb_advantages, ratio)

                    # Value loss
                    ext_v_loss = self.compute_value_loss(new_ext_values, b_ext_returns[mb_inds])
                    int_v_loss = self.compute_value_loss(new_int_values, b_int_returns[mb_inds])
                    v_loss = ext_v_loss + int_v_loss

                    # Entropy loss
                    entropy_loss = entropy.mean()
                    loss = pg_loss - self.args.ent_coef * entropy_loss + v_loss * self.args.vf_coef + self.args.forward_coef * forward_loss

                    self.optimizer.zero_grad()
                    loss.backward()
                    if self.args.max_grad_norm:
                        nn.utils.clip_grad_norm_(
                            self.combined_parameters,
                            self.args.max_grad_norm,
                        )
                    self.optimizer.step()

                if self.args.target_kl is not None:
                    if approx_kl > self.args.target_kl:
                        break

            # record rewards for plotting purposes
            self.writer.add_scalar("charts/learning_rate", self.optimizer.param_groups[0]["lr"], global_step)
            self.writer.add_scalar("losses/value_loss", v_loss.item(), global_step)
            self.writer.add_scalar("losses/policy_loss", pg_loss.item(), global_step)
            self.writer.add_scalar("losses/entropy", entropy_loss.item(), global_step)
            self.tlol.plot_rnd_loss(entropy_loss.item(), global_step)
            self.writer.add_scalar("losses/old_approx_kl", old_approx_kl.item(), global_step)
            self.writer.add_scalar("losses/fwd_loss", forward_loss.item(), global_step)
            self.writer.add_scalar("losses/approx_kl", approx_kl.item(), global_step)
            # print("SPS:", int(global_step / (time.time() - start_time))) # Uncomment if you want to estimate your training speed - should be around 500 steps per second on Colab
            self.tlol.plot_rnd_sps(int(global_step / (time.time() - start_time)), global_step)
            self.writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 class RNDTrainer(PPOTrainer):
#       2     def __init__(self, args, writer, env, agent, rnd_model, tlol):
#       3         super().__init__(args, writer, env, agent, tlol)
#
# NameError: name 'PPOTrainer' is not defined

# %%
args = Args(
    num_steps=32,
    num_workers=8,
    num_envs=128,
    env_id="MiniHack-KeyRoom-S5-v0",
    total_timesteps=1_000_000,
    forward_coef=0.1, 
    int_coef=0.1,
    num_iterations_obs_norm_init=50,
)

# %%
args.batch_size = int(args.num_envs * args.num_steps)
args.minibatch_size = int(args.batch_size // args.num_minibatches)
args.num_iterations = args.total_timesteps // args.batch_size
run_name = f"{args.env_id}__rnd__{args.seed}__{int(time.time())}"

writer = SummaryWriter(f"runs/{run_name}")
writer.add_text(
    "hyperparameters",
    "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
)

# seeding
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = args.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")
env = create_env(args)

agent = Agent(env).to(device)
rnd_model = RNDModel(env).to(device)

trainer = RNDTrainer(args, writer, env, agent, rnd_model, tlol)
trainer.train()

env.close()
writer.close()
# Out:
# Start to initialize observation normalization parameter.....
# End to initialize...
# step=803, 20_avg_episodic_return=0.10000000149011612, curiosity_reward=173.431884765625
# step=847, 20_avg_episodic_return=0.0, curiosity_reward=174.77487182617188
# step=894, 20_avg_episodic_return=0.0, curiosity_reward=174.77487182617188
# step=13348, 20_avg_episodic_return=0.25, curiosity_reward=40.58913040161133
# step=19686, 20_avg_episodic_return=0.10000000149011612, curiosity_reward=24.82132339477539
# step=24625, 20_avg_episodic_return=0.20000000298023224, curiosity_reward=24.870452880859375
# step=26509, 20_avg_episodic_return=0.05000000074505806, curiosity_reward=35.710723876953125
# step=26559, 20_avg_episodic_return=0.0, curiosity_reward=48.71223831176758
# step=26616, 20_avg_episodic_return=0.0, curiosity_reward=48.71223831176758
# step=36488, 20_avg_episodic_return=0.25, curiosity_reward=28.33485984802246
# step=42329, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=24.24622917175293
# step=47940, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=23.93288803100586
# step=50886, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=24.223140716552734
# step=52244, 20_avg_episodic_return=0.10000000149011612, curiosity_reward=29.599945068359375
# step=52316, 20_avg_episodic_return=0.0, curiosity_reward=35.098514556884766
# step=56939, 20_avg_episodic_return=0.10000000149011612, curiosity_reward=31.777673721313477
# step=65473, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=23.497047424316406
# step=70317, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=23.3834171295166
# step=74599, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=23.416919708251953
# step=76950, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=23.571102142333984
# step=78000, 20_avg_episodic_return=0.10000000149011612, curiosity_reward=27.39413833618164
# step=78077, 20_avg_episodic_return=0.0, curiosity_reward=29.936222076416016
# step=85863, 20_avg_episodic_return=0.699999988079071, curiosity_reward=23.26182746887207
# step=91090, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=23.075353622436523
# step=94933, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=23.01116371154785
# step=100201, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=22.924833297729492
# step=103010, 20_avg_episodic_return=0.15000000596046448, curiosity_reward=23.149866104125977
# step=103746, 20_avg_episodic_return=0.10000000149011612, curiosity_reward=26.947513580322266
# step=106324, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=25.67171287536621
# step=112464, 20_avg_episodic_return=0.5, curiosity_reward=22.843151092529297
# step=116929, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=22.949546813964844
# step=119841, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=23.101560592651367
# step=125423, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=22.861108779907227
# step=128106, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=23.108301162719727
# step=129500, 20_avg_episodic_return=0.05000000074505806, curiosity_reward=24.794282913208008
# step=133878, 20_avg_episodic_return=0.25, curiosity_reward=23.801162719726562
# step=137836, 20_avg_episodic_return=0.5, curiosity_reward=22.94263458251953
# step=141384, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=22.919139862060547
# step=144522, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=22.87905502319336
# step=149415, 20_avg_episodic_return=0.25, curiosity_reward=22.67820167541504
# step=153779, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=22.702716827392578
# step=155255, 20_avg_episodic_return=0.15000000596046448, curiosity_reward=23.358081817626953
# step=158391, 20_avg_episodic_return=0.5, curiosity_reward=22.90509033203125
# step=162340, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=22.755313873291016
# step=165292, 20_avg_episodic_return=0.5, curiosity_reward=22.809202194213867
# step=169037, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=22.819751739501953
# step=171752, 20_avg_episodic_return=0.25, curiosity_reward=22.864307403564453
# step=177385, 20_avg_episodic_return=0.25, curiosity_reward=22.71758460998535
# step=180986, 20_avg_episodic_return=0.15000000596046448, curiosity_reward=23.128808975219727
# step=184391, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=22.807968139648438
# step=188068, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=22.80670928955078
# step=191680, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=22.802799224853516
# step=194243, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=22.88893699645996
# step=196697, 20_avg_episodic_return=0.25, curiosity_reward=22.87529945373535
# step=201687, 20_avg_episodic_return=0.5, curiosity_reward=22.713977813720703
# step=206595, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=22.710289001464844
# step=209887, 20_avg_episodic_return=0.15000000596046448, curiosity_reward=22.898616790771484
# step=213171, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=22.80083465576172
# step=216158, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=22.83977699279785
# step=218559, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=22.869089126586914
# step=220493, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=22.83084487915039
# step=222932, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=22.778217315673828
# step=226335, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=22.794775009155273
# step=231018, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=22.702417373657227
# step=234347, 20_avg_episodic_return=0.550000011920929, curiosity_reward=22.800809860229492
# step=238773, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=22.671672821044922
# step=241632, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=22.68547248840332
# step=244722, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=22.67386245727539
# step=247159, 20_avg_episodic_return=0.20000000298023224, curiosity_reward=22.61524772644043
# step=250152, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=22.576242446899414
# step=252886, 20_avg_episodic_return=0.550000011920929, curiosity_reward=22.62202262878418
# step=257540, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=22.521026611328125
# step=260775, 20_avg_episodic_return=0.25, curiosity_reward=22.589397430419922
# step=264675, 20_avg_episodic_return=0.550000011920929, curiosity_reward=22.60044288635254
# step=267387, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=22.693090438842773
# step=270758, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=22.631254196166992
# step=273819, 20_avg_episodic_return=0.25, curiosity_reward=22.564544677734375
# step=276854, 20_avg_episodic_return=0.25, curiosity_reward=22.57805061340332
# step=280359, 20_avg_episodic_return=0.5, curiosity_reward=22.581623077392578
# step=283268, 20_avg_episodic_return=0.6499999761581421, curiosity_reward=22.567214965820312
# step=287424, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=22.55520248413086
# step=290830, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=22.609355926513672
# step=294409, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=22.51508140563965
# step=296895, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=22.581317901611328
# step=299335, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=22.553035736083984
# step=302126, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=22.53424072265625
# step=304799, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=22.62150001525879
# step=307265, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=22.599529266357422
# step=309713, 20_avg_episodic_return=0.550000011920929, curiosity_reward=22.51131820678711
# step=312633, 20_avg_episodic_return=0.75, curiosity_reward=22.493988037109375
# step=315115, 20_avg_episodic_return=0.5, curiosity_reward=22.468021392822266
# step=318181, 20_avg_episodic_return=0.5, curiosity_reward=22.467222213745117
# step=321236, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=22.448776245117188
# step=323708, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=22.486873626708984
# step=326999, 20_avg_episodic_return=0.6499999761581421, curiosity_reward=22.466869354248047
# step=330018, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=22.434650421142578
# step=332807, 20_avg_episodic_return=0.6499999761581421, curiosity_reward=22.466419219970703
# step=335593, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=22.441083908081055
# step=337866, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=22.470218658447266
# step=340952, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=22.403076171875
# step=343467, 20_avg_episodic_return=0.550000011920929, curiosity_reward=22.440568923950195
# step=346238, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=22.41181755065918
# step=348653, 20_avg_episodic_return=0.550000011920929, curiosity_reward=22.462827682495117
# step=351034, 20_avg_episodic_return=0.75, curiosity_reward=22.489845275878906
# step=353515, 20_avg_episodic_return=0.6499999761581421, curiosity_reward=22.355365753173828
# step=356106, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=22.38619613647461
# step=358729, 20_avg_episodic_return=0.699999988079071, curiosity_reward=22.394315719604492
# step=361148, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=22.436655044555664
# step=363894, 20_avg_episodic_return=0.550000011920929, curiosity_reward=22.418704986572266
# step=366777, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=22.40201187133789
# step=369085, 20_avg_episodic_return=0.699999988079071, curiosity_reward=22.4605655670166
# step=371119, 20_avg_episodic_return=0.550000011920929, curiosity_reward=22.437057495117188
# step=372407, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=22.609926223754883
# step=374928, 20_avg_episodic_return=0.6499999761581421, curiosity_reward=22.450468063354492
# step=376646, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.485937118530273
# step=378716, 20_avg_episodic_return=0.75, curiosity_reward=22.414548873901367
# step=380595, 20_avg_episodic_return=0.75, curiosity_reward=22.43276023864746
# step=382414, 20_avg_episodic_return=0.800000011920929, curiosity_reward=22.404001235961914
# step=384633, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.398412704467773
# step=386595, 20_avg_episodic_return=0.800000011920929, curiosity_reward=22.3861026763916
# step=388733, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.367572784423828
# step=391273, 20_avg_episodic_return=0.75, curiosity_reward=22.50617027282715
# step=392804, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.402050018310547
# step=394554, 20_avg_episodic_return=0.699999988079071, curiosity_reward=22.37069320678711
# step=396390, 20_avg_episodic_return=0.800000011920929, curiosity_reward=22.301733016967773
# step=398126, 20_avg_episodic_return=0.699999988079071, curiosity_reward=22.355859756469727
# step=399487, 20_avg_episodic_return=0.800000011920929, curiosity_reward=22.329017639160156
# step=401614, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.260303497314453
# step=402730, 20_avg_episodic_return=0.699999988079071, curiosity_reward=22.495513916015625
# step=405065, 20_avg_episodic_return=0.75, curiosity_reward=22.272441864013672
# step=407768, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=22.286937713623047
# step=409956, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.390336990356445
# step=411858, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=22.328264236450195
# step=413712, 20_avg_episodic_return=0.800000011920929, curiosity_reward=22.359037399291992
# step=416493, 20_avg_episodic_return=0.75, curiosity_reward=22.29551887512207
# step=417918, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.353961944580078
# step=420038, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.358606338500977
# step=422118, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.340564727783203
# step=423963, 20_avg_episodic_return=0.800000011920929, curiosity_reward=22.451099395751953
# step=425940, 20_avg_episodic_return=0.75, curiosity_reward=22.374929428100586
# step=427396, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.406930923461914
# step=428758, 20_avg_episodic_return=0.550000011920929, curiosity_reward=22.52813148498535
# step=430604, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.404464721679688
# step=432624, 20_avg_episodic_return=0.800000011920929, curiosity_reward=22.43598747253418
# step=434532, 20_avg_episodic_return=0.800000011920929, curiosity_reward=22.480106353759766
# step=436206, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=22.738008499145508
# step=437916, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.941604614257812
# step=439366, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=23.207406997680664
# step=440362, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=23.070377349853516
# step=442091, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.775253295898438
# step=443240, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.93770980834961
# step=444940, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.765560150146484
# step=447082, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=22.64168930053711
# step=448738, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.77802276611328
# step=449724, 20_avg_episodic_return=1.0, curiosity_reward=22.983318328857422
# step=451526, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.556522369384766
# step=453243, 20_avg_episodic_return=0.699999988079071, curiosity_reward=22.73984146118164
# step=454467, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.959230422973633
# step=456043, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.755048751831055
# step=457595, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.71383285522461
# step=459075, 20_avg_episodic_return=1.0, curiosity_reward=22.680702209472656
# step=460722, 20_avg_episodic_return=1.0, curiosity_reward=22.579240798950195
# step=462222, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.83811378479004
# step=464071, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.59212875366211
# step=465619, 20_avg_episodic_return=0.800000011920929, curiosity_reward=22.70979118347168
# step=467028, 20_avg_episodic_return=0.800000011920929, curiosity_reward=22.627098083496094
# step=468433, 20_avg_episodic_return=0.800000011920929, curiosity_reward=22.945772171020508
# step=469451, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.692249298095703
# step=471283, 20_avg_episodic_return=1.0, curiosity_reward=22.499114990234375
# step=472891, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.63785743713379
# step=474056, 20_avg_episodic_return=1.0, curiosity_reward=22.69771957397461
# step=475594, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=22.564563751220703
# step=476841, 20_avg_episodic_return=1.0, curiosity_reward=22.61892318725586
# step=478221, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=22.599035263061523
# step=479982, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.584510803222656
# step=481085, 20_avg_episodic_return=1.0, curiosity_reward=22.721527099609375
# step=482155, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=22.72671890258789
# step=483456, 20_avg_episodic_return=1.0, curiosity_reward=22.673931121826172
# step=484830, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.762378692626953
# step=486577, 20_avg_episodic_return=1.0, curiosity_reward=22.590129852294922
# step=487949, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.700969696044922
# step=488935, 20_avg_episodic_return=1.0, curiosity_reward=22.8986759185791
# step=489983, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=22.952844619750977
# step=490945, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.575275421142578
# step=492794, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=22.528066635131836
# step=493711, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.79293441772461
# step=495076, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=22.727991104125977
# step=496205, 20_avg_episodic_return=1.0, curiosity_reward=22.857786178588867
# step=497432, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.72705841064453
# step=498437, 20_avg_episodic_return=1.0, curiosity_reward=22.841136932373047
# step=500013, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=22.77211570739746
# step=501029, 20_avg_episodic_return=1.0, curiosity_reward=22.851024627685547
# step=502393, 20_avg_episodic_return=1.0, curiosity_reward=22.818187713623047
# step=503604, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.891155242919922
# step=504972, 20_avg_episodic_return=1.0, curiosity_reward=22.654239654541016
# step=506405, 20_avg_episodic_return=1.0, curiosity_reward=22.618669509887695
# step=507508, 20_avg_episodic_return=1.0, curiosity_reward=22.734268188476562
# step=509093, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.673377990722656
# step=509976, 20_avg_episodic_return=1.0, curiosity_reward=22.78846549987793
# step=510691, 20_avg_episodic_return=1.0, curiosity_reward=22.847759246826172
# step=512080, 20_avg_episodic_return=1.0, curiosity_reward=22.54258155822754
# step=513447, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.57602882385254
# step=514294, 20_avg_episodic_return=1.0, curiosity_reward=22.877037048339844
# step=515263, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.787044525146484
# step=516637, 20_avg_episodic_return=1.0, curiosity_reward=22.625062942504883
# step=517779, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.81954574584961
# step=518585, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=23.187793731689453
# step=519816, 20_avg_episodic_return=1.0, curiosity_reward=22.525236129760742
# step=521052, 20_avg_episodic_return=1.0, curiosity_reward=22.808483123779297
# step=522181, 20_avg_episodic_return=1.0, curiosity_reward=22.707290649414062
# step=523192, 20_avg_episodic_return=1.0, curiosity_reward=22.725244522094727
# step=524385, 20_avg_episodic_return=1.0, curiosity_reward=22.621185302734375
# step=525629, 20_avg_episodic_return=1.0, curiosity_reward=22.557233810424805
# step=527033, 20_avg_episodic_return=1.0, curiosity_reward=22.501039505004883
# step=527756, 20_avg_episodic_return=1.0, curiosity_reward=22.963424682617188
# step=528964, 20_avg_episodic_return=1.0, curiosity_reward=22.645883560180664
# step=529987, 20_avg_episodic_return=1.0, curiosity_reward=22.63905143737793
# step=531004, 20_avg_episodic_return=1.0, curiosity_reward=22.653202056884766
# step=532255, 20_avg_episodic_return=1.0, curiosity_reward=22.6623592376709
# step=533417, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.7097110748291
# step=534174, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.7381591796875
# step=535560, 20_avg_episodic_return=1.0, curiosity_reward=22.49385643005371
# step=536599, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.74188232421875
# step=537487, 20_avg_episodic_return=1.0, curiosity_reward=22.747671127319336
# step=538741, 20_avg_episodic_return=1.0, curiosity_reward=22.531888961791992
# step=539463, 20_avg_episodic_return=1.0, curiosity_reward=22.912891387939453
# step=540745, 20_avg_episodic_return=1.0, curiosity_reward=22.569644927978516
# step=541588, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=22.654739379882812
# step=542626, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=22.781545639038086
# step=543728, 20_avg_episodic_return=1.0, curiosity_reward=22.567882537841797
# step=544756, 20_avg_episodic_return=1.0, curiosity_reward=22.893978118896484
# step=545460, 20_avg_episodic_return=1.0, curiosity_reward=22.92814064025879
# step=546890, 20_avg_episodic_return=1.0, curiosity_reward=22.537052154541016
# step=547771, 20_avg_episodic_return=1.0, curiosity_reward=22.66164779663086
# step=548821, 20_avg_episodic_return=1.0, curiosity_reward=22.663175582885742
# step=549958, 20_avg_episodic_return=1.0, curiosity_reward=22.6060791015625
# step=550792, 20_avg_episodic_return=1.0, curiosity_reward=23.058887481689453
# step=551517, 20_avg_episodic_return=1.0, curiosity_reward=22.920787811279297
# step=552605, 20_avg_episodic_return=1.0, curiosity_reward=22.746654510498047
# step=553620, 20_avg_episodic_return=1.0, curiosity_reward=22.893407821655273
# step=554281, 20_avg_episodic_return=1.0, curiosity_reward=23.056880950927734
# step=555122, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.861783981323242
# step=556149, 20_avg_episodic_return=1.0, curiosity_reward=23.12970542907715
# step=556989, 20_avg_episodic_return=1.0, curiosity_reward=22.84629249572754
# step=557742, 20_avg_episodic_return=1.0, curiosity_reward=22.867870330810547
# step=558802, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.708120346069336
# step=559773, 20_avg_episodic_return=1.0, curiosity_reward=22.915241241455078
# step=560707, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.932619094848633
# step=561742, 20_avg_episodic_return=1.0, curiosity_reward=22.642375946044922
# step=562678, 20_avg_episodic_return=1.0, curiosity_reward=22.838539123535156
# step=563691, 20_avg_episodic_return=1.0, curiosity_reward=22.74033546447754
# step=564751, 20_avg_episodic_return=1.0, curiosity_reward=22.594417572021484
# step=565787, 20_avg_episodic_return=1.0, curiosity_reward=22.768583297729492
# step=566401, 20_avg_episodic_return=1.0, curiosity_reward=23.22163200378418
# step=567154, 20_avg_episodic_return=1.0, curiosity_reward=23.10152816772461
# step=567926, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.129831314086914
# step=568773, 20_avg_episodic_return=1.0, curiosity_reward=22.79483985900879
# step=569659, 20_avg_episodic_return=1.0, curiosity_reward=22.647985458374023
# step=570626, 20_avg_episodic_return=1.0, curiosity_reward=22.83287239074707
# step=571429, 20_avg_episodic_return=1.0, curiosity_reward=22.995309829711914
# step=571963, 20_avg_episodic_return=1.0, curiosity_reward=23.34026527404785
# step=573074, 20_avg_episodic_return=1.0, curiosity_reward=22.62741470336914
# step=574302, 20_avg_episodic_return=1.0, curiosity_reward=22.94953155517578
# step=575378, 20_avg_episodic_return=1.0, curiosity_reward=23.20656967163086
# step=576011, 20_avg_episodic_return=1.0, curiosity_reward=23.247394561767578
# step=576814, 20_avg_episodic_return=1.0, curiosity_reward=23.230876922607422
# step=577866, 20_avg_episodic_return=1.0, curiosity_reward=22.661113739013672
# step=578858, 20_avg_episodic_return=1.0, curiosity_reward=22.842044830322266
# step=579518, 20_avg_episodic_return=1.0, curiosity_reward=22.982519149780273
# step=580493, 20_avg_episodic_return=1.0, curiosity_reward=22.712316513061523
# step=581657, 20_avg_episodic_return=1.0, curiosity_reward=22.664520263671875
# step=582290, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.977386474609375
# step=583276, 20_avg_episodic_return=1.0, curiosity_reward=22.670188903808594
# step=584152, 20_avg_episodic_return=1.0, curiosity_reward=22.701656341552734
# step=585380, 20_avg_episodic_return=1.0, curiosity_reward=22.45205307006836
# step=586182, 20_avg_episodic_return=1.0, curiosity_reward=23.24909019470215
# step=587102, 20_avg_episodic_return=1.0, curiosity_reward=23.09170150756836
# step=588330, 20_avg_episodic_return=1.0, curiosity_reward=22.55691909790039
# step=589080, 20_avg_episodic_return=1.0, curiosity_reward=23.14063262939453
# step=590154, 20_avg_episodic_return=1.0, curiosity_reward=22.700284957885742
# step=590974, 20_avg_episodic_return=1.0, curiosity_reward=22.666580200195312
# step=591743, 20_avg_episodic_return=1.0, curiosity_reward=23.02972412109375
# step=592703, 20_avg_episodic_return=1.0, curiosity_reward=22.60312843322754
# step=593302, 20_avg_episodic_return=1.0, curiosity_reward=22.967060089111328
# step=593903, 20_avg_episodic_return=1.0, curiosity_reward=23.192392349243164
# step=594921, 20_avg_episodic_return=1.0, curiosity_reward=22.62270164489746
# step=596036, 20_avg_episodic_return=1.0, curiosity_reward=22.589950561523438
# step=596697, 20_avg_episodic_return=1.0, curiosity_reward=23.329885482788086
# step=597414, 20_avg_episodic_return=1.0, curiosity_reward=22.9991512298584
# step=598240, 20_avg_episodic_return=1.0, curiosity_reward=22.80513572692871
# step=598967, 20_avg_episodic_return=1.0, curiosity_reward=22.750539779663086
# step=599721, 20_avg_episodic_return=1.0, curiosity_reward=22.845203399658203
# step=600442, 20_avg_episodic_return=1.0, curiosity_reward=22.86269760131836
# step=601140, 20_avg_episodic_return=1.0, curiosity_reward=23.006587982177734
# step=602129, 20_avg_episodic_return=1.0, curiosity_reward=22.729921340942383
# step=603094, 20_avg_episodic_return=1.0, curiosity_reward=22.65298843383789
# step=603810, 20_avg_episodic_return=1.0, curiosity_reward=22.923778533935547
# step=604958, 20_avg_episodic_return=1.0, curiosity_reward=22.885169982910156
# step=605658, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.96895980834961
# step=606523, 20_avg_episodic_return=1.0, curiosity_reward=22.804058074951172
# step=607409, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.688976287841797
# step=608221, 20_avg_episodic_return=1.0, curiosity_reward=23.01045799255371
# step=609088, 20_avg_episodic_return=1.0, curiosity_reward=22.811996459960938
# step=609792, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.87595558166504
# step=610393, 20_avg_episodic_return=1.0, curiosity_reward=23.05213737487793
# step=611155, 20_avg_episodic_return=1.0, curiosity_reward=23.069732666015625
# step=611868, 20_avg_episodic_return=1.0, curiosity_reward=22.84343910217285
# step=612492, 20_avg_episodic_return=1.0, curiosity_reward=23.05649185180664
# step=613354, 20_avg_episodic_return=1.0, curiosity_reward=23.072208404541016
# step=614555, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.781635284423828
# step=615381, 20_avg_episodic_return=1.0, curiosity_reward=22.758026123046875
# step=616304, 20_avg_episodic_return=1.0, curiosity_reward=22.78249168395996
# step=616940, 20_avg_episodic_return=1.0, curiosity_reward=23.1478328704834
# step=617783, 20_avg_episodic_return=1.0, curiosity_reward=22.800914764404297
# step=618635, 20_avg_episodic_return=1.0, curiosity_reward=22.71582794189453
# step=619458, 20_avg_episodic_return=1.0, curiosity_reward=22.77048110961914
# step=620097, 20_avg_episodic_return=1.0, curiosity_reward=23.27410888671875
# step=620671, 20_avg_episodic_return=1.0, curiosity_reward=24.257966995239258
# step=621652, 20_avg_episodic_return=1.0, curiosity_reward=22.558704376220703
# step=622428, 20_avg_episodic_return=1.0, curiosity_reward=22.685623168945312
# step=623175, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.001352310180664
# step=623885, 20_avg_episodic_return=1.0, curiosity_reward=22.942169189453125
# step=624695, 20_avg_episodic_return=1.0, curiosity_reward=23.034915924072266
# step=625704, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.544721603393555
# step=626337, 20_avg_episodic_return=1.0, curiosity_reward=22.894184112548828
# step=627028, 20_avg_episodic_return=1.0, curiosity_reward=22.8385066986084
# step=627887, 20_avg_episodic_return=1.0, curiosity_reward=22.726186752319336
# step=628778, 20_avg_episodic_return=1.0, curiosity_reward=22.656728744506836
# step=629252, 20_avg_episodic_return=1.0, curiosity_reward=23.255163192749023
# step=630194, 20_avg_episodic_return=1.0, curiosity_reward=22.709238052368164
# step=630865, 20_avg_episodic_return=1.0, curiosity_reward=22.8450870513916
# step=631739, 20_avg_episodic_return=1.0, curiosity_reward=22.752910614013672
# step=632405, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.019765853881836
# step=633009, 20_avg_episodic_return=1.0, curiosity_reward=23.241971969604492
# step=633850, 20_avg_episodic_return=1.0, curiosity_reward=22.65176010131836
# step=634373, 20_avg_episodic_return=1.0, curiosity_reward=23.340147018432617
# step=635276, 20_avg_episodic_return=1.0, curiosity_reward=22.647815704345703
# step=635756, 20_avg_episodic_return=1.0, curiosity_reward=23.382198333740234
# step=636369, 20_avg_episodic_return=1.0, curiosity_reward=23.132553100585938
# step=637441, 20_avg_episodic_return=1.0, curiosity_reward=22.445049285888672
# step=638188, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.9556827545166
# step=638900, 20_avg_episodic_return=1.0, curiosity_reward=22.840282440185547
# step=639474, 20_avg_episodic_return=1.0, curiosity_reward=23.08831214904785
# step=640095, 20_avg_episodic_return=1.0, curiosity_reward=22.8773136138916
# step=640602, 20_avg_episodic_return=1.0, curiosity_reward=23.223705291748047
# step=641308, 20_avg_episodic_return=1.0, curiosity_reward=22.590316772460938
# step=642254, 20_avg_episodic_return=1.0, curiosity_reward=22.65048599243164
# step=642886, 20_avg_episodic_return=1.0, curiosity_reward=22.9582576751709
# step=643478, 20_avg_episodic_return=1.0, curiosity_reward=22.893936157226562
# step=644338, 20_avg_episodic_return=0.949999988079071, curiosity_reward=22.71206283569336
# step=645259, 20_avg_episodic_return=1.0, curiosity_reward=23.13827133178711
# step=645838, 20_avg_episodic_return=1.0, curiosity_reward=23.129962921142578
# step=646564, 20_avg_episodic_return=1.0, curiosity_reward=23.06813621520996
# step=647286, 20_avg_episodic_return=1.0, curiosity_reward=23.249536514282227
# step=647961, 20_avg_episodic_return=1.0, curiosity_reward=23.052427291870117
# step=648690, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.199111938476562
# step=649137, 20_avg_episodic_return=1.0, curiosity_reward=23.57314682006836
# step=649925, 20_avg_episodic_return=1.0, curiosity_reward=22.972789764404297
# step=650917, 20_avg_episodic_return=1.0, curiosity_reward=22.899311065673828
# step=651382, 20_avg_episodic_return=1.0, curiosity_reward=23.551822662353516
# step=651872, 20_avg_episodic_return=1.0, curiosity_reward=23.599987030029297
# step=652470, 20_avg_episodic_return=1.0, curiosity_reward=23.22310447692871
# step=653237, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.22989273071289
# step=654021, 20_avg_episodic_return=1.0, curiosity_reward=22.897357940673828
# step=654717, 20_avg_episodic_return=1.0, curiosity_reward=23.383441925048828
# step=655472, 20_avg_episodic_return=1.0, curiosity_reward=23.049898147583008
# step=655868, 20_avg_episodic_return=1.0, curiosity_reward=23.974390029907227
# step=656543, 20_avg_episodic_return=1.0, curiosity_reward=23.25381088256836
# step=657330, 20_avg_episodic_return=1.0, curiosity_reward=23.132038116455078
# step=658030, 20_avg_episodic_return=1.0, curiosity_reward=23.126995086669922
# step=658654, 20_avg_episodic_return=1.0, curiosity_reward=23.444660186767578
# step=659179, 20_avg_episodic_return=1.0, curiosity_reward=23.502342224121094
# step=659982, 20_avg_episodic_return=1.0, curiosity_reward=23.245670318603516
# step=660640, 20_avg_episodic_return=1.0, curiosity_reward=23.328590393066406
# step=661261, 20_avg_episodic_return=1.0, curiosity_reward=23.333484649658203
# step=661748, 20_avg_episodic_return=1.0, curiosity_reward=23.527889251708984
# step=662732, 20_avg_episodic_return=1.0, curiosity_reward=22.98324966430664
# step=663471, 20_avg_episodic_return=1.0, curiosity_reward=23.140403747558594
# step=664282, 20_avg_episodic_return=1.0, curiosity_reward=23.034908294677734
# step=665048, 20_avg_episodic_return=1.0, curiosity_reward=23.033294677734375
# step=665508, 20_avg_episodic_return=1.0, curiosity_reward=23.62848472595215
# step=666185, 20_avg_episodic_return=1.0, curiosity_reward=23.528188705444336
# step=666836, 20_avg_episodic_return=1.0, curiosity_reward=23.439342498779297
# step=667723, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.03121566772461
# step=668535, 20_avg_episodic_return=1.0, curiosity_reward=23.016948699951172
# step=669117, 20_avg_episodic_return=1.0, curiosity_reward=23.417524337768555
# step=669796, 20_avg_episodic_return=1.0, curiosity_reward=23.06692123413086
# step=670575, 20_avg_episodic_return=1.0, curiosity_reward=23.36924934387207
# step=671278, 20_avg_episodic_return=1.0, curiosity_reward=22.96240234375
# step=671952, 20_avg_episodic_return=1.0, curiosity_reward=23.401775360107422
# step=672789, 20_avg_episodic_return=1.0, curiosity_reward=23.42910385131836
# step=673380, 20_avg_episodic_return=1.0, curiosity_reward=23.414419174194336
# step=674054, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.73150634765625
# step=674793, 20_avg_episodic_return=1.0, curiosity_reward=23.378311157226562
# step=675547, 20_avg_episodic_return=1.0, curiosity_reward=23.225860595703125
# step=676271, 20_avg_episodic_return=1.0, curiosity_reward=23.587841033935547
# step=676908, 20_avg_episodic_return=1.0, curiosity_reward=23.800111770629883
# step=677570, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.237781524658203
# step=678317, 20_avg_episodic_return=1.0, curiosity_reward=23.20877456665039
# step=679118, 20_avg_episodic_return=1.0, curiosity_reward=23.192914962768555
# step=679645, 20_avg_episodic_return=1.0, curiosity_reward=24.025482177734375
# step=680124, 20_avg_episodic_return=1.0, curiosity_reward=23.78073501586914
# step=680698, 20_avg_episodic_return=1.0, curiosity_reward=23.805484771728516
# step=681363, 20_avg_episodic_return=1.0, curiosity_reward=23.369792938232422
# step=682255, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.07828140258789
# step=682747, 20_avg_episodic_return=1.0, curiosity_reward=24.59624671936035
# step=683280, 20_avg_episodic_return=1.0, curiosity_reward=23.597387313842773
# step=683904, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.536705017089844
# step=684551, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.478534698486328
# step=684985, 20_avg_episodic_return=1.0, curiosity_reward=24.529348373413086
# step=685610, 20_avg_episodic_return=1.0, curiosity_reward=23.43805694580078
# step=686399, 20_avg_episodic_return=1.0, curiosity_reward=23.310054779052734
# step=687145, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.17690658569336
# step=687835, 20_avg_episodic_return=1.0, curiosity_reward=23.256887435913086
# step=688455, 20_avg_episodic_return=1.0, curiosity_reward=23.584808349609375
# step=689026, 20_avg_episodic_return=1.0, curiosity_reward=23.675249099731445
# step=689631, 20_avg_episodic_return=1.0, curiosity_reward=23.526641845703125
# step=690486, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=23.310274124145508
# step=691037, 20_avg_episodic_return=1.0, curiosity_reward=23.390844345092773
# step=691650, 20_avg_episodic_return=1.0, curiosity_reward=23.43857192993164
# step=692403, 20_avg_episodic_return=1.0, curiosity_reward=23.157745361328125
# step=693075, 20_avg_episodic_return=1.0, curiosity_reward=23.364696502685547
# step=693755, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.13888931274414
# step=694302, 20_avg_episodic_return=1.0, curiosity_reward=23.788612365722656
# step=694845, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.72536849975586
# step=695554, 20_avg_episodic_return=1.0, curiosity_reward=23.300861358642578
# step=696076, 20_avg_episodic_return=1.0, curiosity_reward=23.540071487426758
# step=696775, 20_avg_episodic_return=1.0, curiosity_reward=23.237335205078125
# step=697376, 20_avg_episodic_return=1.0, curiosity_reward=23.377517700195312
# step=697997, 20_avg_episodic_return=1.0, curiosity_reward=23.351898193359375
# step=698596, 20_avg_episodic_return=1.0, curiosity_reward=23.707996368408203
# step=699225, 20_avg_episodic_return=1.0, curiosity_reward=23.459041595458984
# step=699943, 20_avg_episodic_return=1.0, curiosity_reward=23.214962005615234
# step=700615, 20_avg_episodic_return=1.0, curiosity_reward=23.380273818969727
# step=701191, 20_avg_episodic_return=1.0, curiosity_reward=23.323911666870117
# step=701607, 20_avg_episodic_return=1.0, curiosity_reward=23.82795524597168
# step=702228, 20_avg_episodic_return=1.0, curiosity_reward=23.254745483398438
# step=702845, 20_avg_episodic_return=1.0, curiosity_reward=23.285619735717773
# step=703418, 20_avg_episodic_return=1.0, curiosity_reward=23.638540267944336
# step=704047, 20_avg_episodic_return=1.0, curiosity_reward=23.511232376098633
# step=704630, 20_avg_episodic_return=1.0, curiosity_reward=23.16644287109375
# step=705220, 20_avg_episodic_return=1.0, curiosity_reward=23.441402435302734
# step=705799, 20_avg_episodic_return=1.0, curiosity_reward=23.50597381591797
# step=706339, 20_avg_episodic_return=1.0, curiosity_reward=23.58605194091797
# step=706954, 20_avg_episodic_return=1.0, curiosity_reward=23.729772567749023
# step=707369, 20_avg_episodic_return=1.0, curiosity_reward=24.162334442138672
# step=707767, 20_avg_episodic_return=1.0, curiosity_reward=24.006927490234375
# step=708623, 20_avg_episodic_return=1.0, curiosity_reward=23.089330673217773
# step=709008, 20_avg_episodic_return=1.0, curiosity_reward=24.085237503051758
# step=709389, 20_avg_episodic_return=1.0, curiosity_reward=24.025836944580078
# step=709963, 20_avg_episodic_return=1.0, curiosity_reward=23.530302047729492
# step=710536, 20_avg_episodic_return=1.0, curiosity_reward=23.2148380279541
# step=711037, 20_avg_episodic_return=1.0, curiosity_reward=24.078527450561523
# step=711679, 20_avg_episodic_return=1.0, curiosity_reward=23.369129180908203
# step=712244, 20_avg_episodic_return=1.0, curiosity_reward=23.497135162353516
# step=712688, 20_avg_episodic_return=1.0, curiosity_reward=23.79581069946289
# step=713339, 20_avg_episodic_return=1.0, curiosity_reward=23.23312759399414
# step=713931, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.427288055419922
# step=714549, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.43305206298828
# step=715069, 20_avg_episodic_return=1.0, curiosity_reward=23.486860275268555
# step=715646, 20_avg_episodic_return=1.0, curiosity_reward=23.53135871887207
# step=716175, 20_avg_episodic_return=1.0, curiosity_reward=23.752315521240234
# step=716700, 20_avg_episodic_return=1.0, curiosity_reward=23.59083366394043
# step=717391, 20_avg_episodic_return=1.0, curiosity_reward=23.394672393798828
# step=717879, 20_avg_episodic_return=1.0, curiosity_reward=23.518436431884766
# step=718587, 20_avg_episodic_return=1.0, curiosity_reward=23.60262680053711
# step=719113, 20_avg_episodic_return=1.0, curiosity_reward=23.63308334350586
# step=719656, 20_avg_episodic_return=1.0, curiosity_reward=23.55474090576172
# step=720535, 20_avg_episodic_return=1.0, curiosity_reward=22.877973556518555
# step=720829, 20_avg_episodic_return=1.0, curiosity_reward=24.769433975219727
# step=721335, 20_avg_episodic_return=1.0, curiosity_reward=23.97838592529297
# step=721979, 20_avg_episodic_return=1.0, curiosity_reward=23.39445686340332
# step=722540, 20_avg_episodic_return=1.0, curiosity_reward=23.444534301757812
# step=723170, 20_avg_episodic_return=1.0, curiosity_reward=23.32571792602539
# step=723691, 20_avg_episodic_return=1.0, curiosity_reward=24.24188995361328
# step=724127, 20_avg_episodic_return=1.0, curiosity_reward=24.206668853759766
# step=724541, 20_avg_episodic_return=1.0, curiosity_reward=23.587112426757812
# step=725183, 20_avg_episodic_return=1.0, curiosity_reward=23.331838607788086
# step=725873, 20_avg_episodic_return=1.0, curiosity_reward=23.584415435791016
# step=726341, 20_avg_episodic_return=1.0, curiosity_reward=23.965606689453125
# step=726956, 20_avg_episodic_return=1.0, curiosity_reward=23.50891876220703
# step=727576, 20_avg_episodic_return=1.0, curiosity_reward=23.392000198364258
# step=728063, 20_avg_episodic_return=1.0, curiosity_reward=23.67007064819336
# step=728662, 20_avg_episodic_return=1.0, curiosity_reward=23.38351058959961
# step=729172, 20_avg_episodic_return=1.0, curiosity_reward=23.581811904907227
# step=730023, 20_avg_episodic_return=1.0, curiosity_reward=22.994754791259766
# step=730629, 20_avg_episodic_return=1.0, curiosity_reward=23.502853393554688
# step=731027, 20_avg_episodic_return=1.0, curiosity_reward=24.134191513061523
# step=731681, 20_avg_episodic_return=1.0, curiosity_reward=23.22083282470703
# step=732199, 20_avg_episodic_return=1.0, curiosity_reward=23.934953689575195
# step=732570, 20_avg_episodic_return=1.0, curiosity_reward=24.583749771118164
# step=733373, 20_avg_episodic_return=1.0, curiosity_reward=23.060392379760742
# step=733804, 20_avg_episodic_return=1.0, curiosity_reward=23.923847198486328
# step=734556, 20_avg_episodic_return=1.0, curiosity_reward=23.06747055053711
# step=735170, 20_avg_episodic_return=1.0, curiosity_reward=23.41922950744629
# step=735686, 20_avg_episodic_return=1.0, curiosity_reward=23.926624298095703
# step=736277, 20_avg_episodic_return=1.0, curiosity_reward=23.390995025634766
# step=736858, 20_avg_episodic_return=1.0, curiosity_reward=23.475109100341797
# step=737369, 20_avg_episodic_return=1.0, curiosity_reward=23.71233367919922
# step=738139, 20_avg_episodic_return=1.0, curiosity_reward=23.59750747680664
# step=738648, 20_avg_episodic_return=1.0, curiosity_reward=24.01349449157715
# step=739122, 20_avg_episodic_return=1.0, curiosity_reward=23.73804473876953
# step=739775, 20_avg_episodic_return=1.0, curiosity_reward=23.38827896118164
# step=740492, 20_avg_episodic_return=1.0, curiosity_reward=23.413715362548828
# step=741163, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.447185516357422
# step=741545, 20_avg_episodic_return=1.0, curiosity_reward=24.14678955078125
# step=742178, 20_avg_episodic_return=1.0, curiosity_reward=23.609477996826172
# step=742877, 20_avg_episodic_return=1.0, curiosity_reward=23.695133209228516
# step=743464, 20_avg_episodic_return=1.0, curiosity_reward=23.40909194946289
# step=743799, 20_avg_episodic_return=1.0, curiosity_reward=24.316736221313477
# step=744260, 20_avg_episodic_return=1.0, curiosity_reward=23.892438888549805
# step=744885, 20_avg_episodic_return=1.0, curiosity_reward=23.373394012451172
# step=745540, 20_avg_episodic_return=1.0, curiosity_reward=23.543048858642578
# step=745994, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.898725509643555
# step=746545, 20_avg_episodic_return=1.0, curiosity_reward=23.480051040649414
# step=747199, 20_avg_episodic_return=1.0, curiosity_reward=23.302621841430664
# step=747741, 20_avg_episodic_return=1.0, curiosity_reward=23.640865325927734
# step=748189, 20_avg_episodic_return=1.0, curiosity_reward=24.000612258911133
# step=748726, 20_avg_episodic_return=1.0, curiosity_reward=23.5064640045166
# step=749391, 20_avg_episodic_return=1.0, curiosity_reward=23.345394134521484
# step=749941, 20_avg_episodic_return=1.0, curiosity_reward=23.67978286743164
# step=750448, 20_avg_episodic_return=1.0, curiosity_reward=23.65378761291504
# step=750888, 20_avg_episodic_return=1.0, curiosity_reward=23.903400421142578
# step=751399, 20_avg_episodic_return=1.0, curiosity_reward=24.03982925415039
# step=752083, 20_avg_episodic_return=1.0, curiosity_reward=23.336265563964844
# step=752530, 20_avg_episodic_return=1.0, curiosity_reward=24.034828186035156
# step=753204, 20_avg_episodic_return=1.0, curiosity_reward=23.760692596435547
# step=753864, 20_avg_episodic_return=1.0, curiosity_reward=23.45911979675293
# step=754343, 20_avg_episodic_return=1.0, curiosity_reward=23.649320602416992
# step=754847, 20_avg_episodic_return=1.0, curiosity_reward=23.924495697021484
# step=755274, 20_avg_episodic_return=1.0, curiosity_reward=24.58614158630371
# step=755832, 20_avg_episodic_return=1.0, curiosity_reward=23.884185791015625
# step=756383, 20_avg_episodic_return=1.0, curiosity_reward=23.554149627685547
# step=756848, 20_avg_episodic_return=1.0, curiosity_reward=23.945270538330078
# step=757437, 20_avg_episodic_return=1.0, curiosity_reward=23.61457061767578
# step=758038, 20_avg_episodic_return=1.0, curiosity_reward=23.568714141845703
# step=758403, 20_avg_episodic_return=1.0, curiosity_reward=24.25836181640625
# step=758861, 20_avg_episodic_return=1.0, curiosity_reward=23.848949432373047
# step=759431, 20_avg_episodic_return=1.0, curiosity_reward=23.520179748535156
# step=759888, 20_avg_episodic_return=1.0, curiosity_reward=23.872634887695312
# step=760447, 20_avg_episodic_return=1.0, curiosity_reward=23.607633590698242
# step=761102, 20_avg_episodic_return=1.0, curiosity_reward=23.39583969116211
# step=761716, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.409765243530273
# step=762255, 20_avg_episodic_return=1.0, curiosity_reward=23.716022491455078
# step=762727, 20_avg_episodic_return=1.0, curiosity_reward=23.75365447998047
# step=763209, 20_avg_episodic_return=1.0, curiosity_reward=23.7825927734375
# step=763704, 20_avg_episodic_return=1.0, curiosity_reward=23.842802047729492
# step=764150, 20_avg_episodic_return=1.0, curiosity_reward=23.874168395996094
# step=764929, 20_avg_episodic_return=1.0, curiosity_reward=23.120370864868164
# step=765436, 20_avg_episodic_return=1.0, curiosity_reward=23.795093536376953
# step=765951, 20_avg_episodic_return=1.0, curiosity_reward=23.79327392578125
# step=766410, 20_avg_episodic_return=1.0, curiosity_reward=23.76858139038086
# step=766731, 20_avg_episodic_return=1.0, curiosity_reward=24.611133575439453
# step=767151, 20_avg_episodic_return=1.0, curiosity_reward=23.84381675720215
# step=767835, 20_avg_episodic_return=1.0, curiosity_reward=23.425569534301758
# step=768578, 20_avg_episodic_return=1.0, curiosity_reward=23.190813064575195
# step=768982, 20_avg_episodic_return=1.0, curiosity_reward=24.099002838134766
# step=769506, 20_avg_episodic_return=1.0, curiosity_reward=23.878087997436523
# step=769931, 20_avg_episodic_return=1.0, curiosity_reward=24.205373764038086
# step=770332, 20_avg_episodic_return=1.0, curiosity_reward=23.98979949951172
# step=770995, 20_avg_episodic_return=1.0, curiosity_reward=23.39059066772461
# step=771655, 20_avg_episodic_return=1.0, curiosity_reward=23.445600509643555
# step=772119, 20_avg_episodic_return=0.949999988079071, curiosity_reward=23.8859920501709
# step=772546, 20_avg_episodic_return=1.0, curiosity_reward=23.921228408813477
# step=773030, 20_avg_episodic_return=1.0, curiosity_reward=23.56998062133789
# step=773704, 20_avg_episodic_return=1.0, curiosity_reward=23.540164947509766
# step=774359, 20_avg_episodic_return=1.0, curiosity_reward=23.42940330505371
# step=774741, 20_avg_episodic_return=1.0, curiosity_reward=24.11180305480957
# step=775345, 20_avg_episodic_return=1.0, curiosity_reward=23.371320724487305
# step=775775, 20_avg_episodic_return=1.0, curiosity_reward=24.069751739501953
# step=776296, 20_avg_episodic_return=1.0, curiosity_reward=23.761241912841797
# step=777021, 20_avg_episodic_return=1.0, curiosity_reward=23.363853454589844
# step=777565, 20_avg_episodic_return=1.0, curiosity_reward=23.73874282836914
# step=778089, 20_avg_episodic_return=1.0, curiosity_reward=23.997211456298828
# step=778585, 20_avg_episodic_return=1.0, curiosity_reward=23.581506729125977
# step=779118, 20_avg_episodic_return=1.0, curiosity_reward=23.58261489868164
# step=779553, 20_avg_episodic_return=1.0, curiosity_reward=23.749446868896484
# step=780000, 20_avg_episodic_return=1.0, curiosity_reward=24.316715240478516
# step=780663, 20_avg_episodic_return=1.0, curiosity_reward=23.467390060424805
# step=781097, 20_avg_episodic_return=1.0, curiosity_reward=23.990726470947266
# step=781591, 20_avg_episodic_return=1.0, curiosity_reward=23.61746597290039
# step=782172, 20_avg_episodic_return=1.0, curiosity_reward=23.868349075317383
# step=782628, 20_avg_episodic_return=1.0, curiosity_reward=23.882658004760742
# step=783033, 20_avg_episodic_return=1.0, curiosity_reward=23.998291015625
# step=783678, 20_avg_episodic_return=1.0, curiosity_reward=23.60947608947754
# step=784310, 20_avg_episodic_return=1.0, curiosity_reward=23.602062225341797
# step=784667, 20_avg_episodic_return=1.0, curiosity_reward=24.4753360748291
# step=785133, 20_avg_episodic_return=1.0, curiosity_reward=23.8115234375
# step=785792, 20_avg_episodic_return=1.0, curiosity_reward=23.62477684020996
# ...
# step=910071, 20_avg_episodic_return=1.0, curiosity_reward=26.580184936523438
# step=910532, 20_avg_episodic_return=1.0, curiosity_reward=26.34231185913086
# step=911049, 20_avg_episodic_return=1.0, curiosity_reward=26.072097778320312
# step=911666, 20_avg_episodic_return=1.0, curiosity_reward=25.420928955078125
# step=912027, 20_avg_episodic_return=1.0, curiosity_reward=28.231225967407227
# step=912529, 20_avg_episodic_return=1.0, curiosity_reward=26.243459701538086
# step=912927, 20_avg_episodic_return=1.0, curiosity_reward=26.935428619384766
# step=913367, 20_avg_episodic_return=1.0, curiosity_reward=26.86606788635254
# step=913912, 20_avg_episodic_return=1.0, curiosity_reward=25.981475830078125
# step=914357, 20_avg_episodic_return=1.0, curiosity_reward=26.87355613708496
# step=914938, 20_avg_episodic_return=1.0, curiosity_reward=26.67276954650879
# step=915371, 20_avg_episodic_return=1.0, curiosity_reward=27.564441680908203
# step=915827, 20_avg_episodic_return=1.0, curiosity_reward=26.570486068725586
# step=916159, 20_avg_episodic_return=1.0, curiosity_reward=27.358795166015625
# step=916616, 20_avg_episodic_return=1.0, curiosity_reward=27.012958526611328
# step=916928, 20_avg_episodic_return=1.0, curiosity_reward=28.966434478759766
# step=917338, 20_avg_episodic_return=1.0, curiosity_reward=27.1807861328125
# step=917834, 20_avg_episodic_return=1.0, curiosity_reward=27.39523696899414
# step=918369, 20_avg_episodic_return=1.0, curiosity_reward=25.77907943725586
# step=918627, 20_avg_episodic_return=1.0, curiosity_reward=29.381750106811523
# step=919045, 20_avg_episodic_return=1.0, curiosity_reward=28.212448120117188
# step=919614, 20_avg_episodic_return=1.0, curiosity_reward=25.501537322998047
# step=920060, 20_avg_episodic_return=1.0, curiosity_reward=26.91290283203125
# step=920418, 20_avg_episodic_return=1.0, curiosity_reward=27.8861083984375
# step=920782, 20_avg_episodic_return=1.0, curiosity_reward=26.823177337646484
# step=921289, 20_avg_episodic_return=1.0, curiosity_reward=26.00026512145996
# step=921736, 20_avg_episodic_return=1.0, curiosity_reward=26.477222442626953
# step=922106, 20_avg_episodic_return=1.0, curiosity_reward=27.36307144165039
# step=922830, 20_avg_episodic_return=1.0, curiosity_reward=25.095081329345703
# step=923182, 20_avg_episodic_return=1.0, curiosity_reward=28.175350189208984
# step=923547, 20_avg_episodic_return=1.0, curiosity_reward=26.906147003173828
# step=923978, 20_avg_episodic_return=1.0, curiosity_reward=27.7232608795166
# step=924380, 20_avg_episodic_return=1.0, curiosity_reward=27.37721824645996
# step=924829, 20_avg_episodic_return=1.0, curiosity_reward=26.314105987548828
# step=925245, 20_avg_episodic_return=1.0, curiosity_reward=28.063100814819336
# step=925686, 20_avg_episodic_return=1.0, curiosity_reward=28.406042098999023
# step=926103, 20_avg_episodic_return=1.0, curiosity_reward=26.529403686523438
# step=926543, 20_avg_episodic_return=1.0, curiosity_reward=27.079975128173828
# step=927037, 20_avg_episodic_return=1.0, curiosity_reward=28.665639877319336
# step=927376, 20_avg_episodic_return=1.0, curiosity_reward=27.94492530822754
# step=927920, 20_avg_episodic_return=1.0, curiosity_reward=26.466083526611328
# step=928332, 20_avg_episodic_return=1.0, curiosity_reward=27.6991024017334
# step=928672, 20_avg_episodic_return=1.0, curiosity_reward=26.88161277770996
# step=929055, 20_avg_episodic_return=1.0, curiosity_reward=28.737295150756836
# step=929498, 20_avg_episodic_return=1.0, curiosity_reward=26.678115844726562
# step=929927, 20_avg_episodic_return=1.0, curiosity_reward=27.489578247070312
# step=930309, 20_avg_episodic_return=1.0, curiosity_reward=27.090383529663086
# step=930672, 20_avg_episodic_return=1.0, curiosity_reward=28.0093994140625
# step=931186, 20_avg_episodic_return=1.0, curiosity_reward=26.396068572998047
# step=931650, 20_avg_episodic_return=1.0, curiosity_reward=26.157543182373047
# step=932156, 20_avg_episodic_return=1.0, curiosity_reward=26.05471420288086
# step=932564, 20_avg_episodic_return=1.0, curiosity_reward=27.666980743408203
# step=932890, 20_avg_episodic_return=1.0, curiosity_reward=27.73319435119629
# step=933330, 20_avg_episodic_return=1.0, curiosity_reward=27.113473892211914
# step=933717, 20_avg_episodic_return=1.0, curiosity_reward=26.32407569885254
# step=934176, 20_avg_episodic_return=1.0, curiosity_reward=27.437740325927734
# step=934550, 20_avg_episodic_return=1.0, curiosity_reward=27.011938095092773
# step=934994, 20_avg_episodic_return=1.0, curiosity_reward=26.52644920349121
# step=935542, 20_avg_episodic_return=1.0, curiosity_reward=26.143123626708984
# step=935931, 20_avg_episodic_return=1.0, curiosity_reward=27.686565399169922
# step=936394, 20_avg_episodic_return=1.0, curiosity_reward=26.248737335205078
# step=936931, 20_avg_episodic_return=1.0, curiosity_reward=26.083812713623047
# step=937333, 20_avg_episodic_return=1.0, curiosity_reward=27.226917266845703
# step=937748, 20_avg_episodic_return=1.0, curiosity_reward=26.554489135742188
# step=938219, 20_avg_episodic_return=1.0, curiosity_reward=26.688365936279297
# step=938607, 20_avg_episodic_return=1.0, curiosity_reward=27.864471435546875
# step=939073, 20_avg_episodic_return=1.0, curiosity_reward=26.768285751342773
# step=939487, 20_avg_episodic_return=1.0, curiosity_reward=27.489309310913086
# step=939890, 20_avg_episodic_return=1.0, curiosity_reward=27.06941795349121
# step=940351, 20_avg_episodic_return=1.0, curiosity_reward=26.425582885742188
# step=940780, 20_avg_episodic_return=1.0, curiosity_reward=26.805599212646484
# step=941273, 20_avg_episodic_return=1.0, curiosity_reward=27.082096099853516
# step=941643, 20_avg_episodic_return=1.0, curiosity_reward=27.56277847290039
# step=942023, 20_avg_episodic_return=1.0, curiosity_reward=27.673152923583984
# step=942560, 20_avg_episodic_return=1.0, curiosity_reward=25.98235511779785
# step=943070, 20_avg_episodic_return=1.0, curiosity_reward=26.085445404052734
# step=943555, 20_avg_episodic_return=1.0, curiosity_reward=27.01153564453125
# step=944091, 20_avg_episodic_return=1.0, curiosity_reward=26.397396087646484
# step=944487, 20_avg_episodic_return=1.0, curiosity_reward=27.3658390045166
# step=944873, 20_avg_episodic_return=0.949999988079071, curiosity_reward=27.428558349609375
# step=945288, 20_avg_episodic_return=1.0, curiosity_reward=27.182144165039062
# step=945737, 20_avg_episodic_return=1.0, curiosity_reward=26.28564453125
# step=946146, 20_avg_episodic_return=1.0, curiosity_reward=27.348974227905273
# step=946492, 20_avg_episodic_return=0.949999988079071, curiosity_reward=27.67061424255371
# step=947011, 20_avg_episodic_return=1.0, curiosity_reward=26.674213409423828
# step=947486, 20_avg_episodic_return=1.0, curiosity_reward=26.327138900756836
# step=948006, 20_avg_episodic_return=1.0, curiosity_reward=26.19830322265625
# step=948457, 20_avg_episodic_return=1.0, curiosity_reward=26.8171329498291
# step=948883, 20_avg_episodic_return=1.0, curiosity_reward=26.339954376220703
# step=949210, 20_avg_episodic_return=1.0, curiosity_reward=27.68343734741211
# step=949632, 20_avg_episodic_return=1.0, curiosity_reward=27.028518676757812
# step=950051, 20_avg_episodic_return=1.0, curiosity_reward=26.70902442932129
# step=950444, 20_avg_episodic_return=1.0, curiosity_reward=27.46024513244629
# step=950965, 20_avg_episodic_return=1.0, curiosity_reward=25.482418060302734
# step=951421, 20_avg_episodic_return=1.0, curiosity_reward=26.706653594970703
# step=951874, 20_avg_episodic_return=1.0, curiosity_reward=27.465099334716797
# step=952201, 20_avg_episodic_return=1.0, curiosity_reward=28.222415924072266
# step=952701, 20_avg_episodic_return=1.0, curiosity_reward=26.368408203125
# step=953053, 20_avg_episodic_return=1.0, curiosity_reward=27.159805297851562
# step=953377, 20_avg_episodic_return=1.0, curiosity_reward=27.60845375061035
# step=953787, 20_avg_episodic_return=1.0, curiosity_reward=27.922887802124023
# step=954335, 20_avg_episodic_return=1.0, curiosity_reward=25.828628540039062
# step=954921, 20_avg_episodic_return=1.0, curiosity_reward=26.813827514648438
# step=955291, 20_avg_episodic_return=1.0, curiosity_reward=27.565317153930664
# step=955727, 20_avg_episodic_return=1.0, curiosity_reward=27.10788917541504
# step=956087, 20_avg_episodic_return=1.0, curiosity_reward=27.829275131225586
# step=956611, 20_avg_episodic_return=1.0, curiosity_reward=26.357656478881836
# step=956984, 20_avg_episodic_return=1.0, curiosity_reward=26.598587036132812
# step=957334, 20_avg_episodic_return=1.0, curiosity_reward=27.863418579101562
# step=957804, 20_avg_episodic_return=1.0, curiosity_reward=27.10520362854004
# step=958197, 20_avg_episodic_return=1.0, curiosity_reward=29.061553955078125
# step=958580, 20_avg_episodic_return=1.0, curiosity_reward=26.65817642211914
# step=958984, 20_avg_episodic_return=1.0, curiosity_reward=28.417953491210938
# step=959434, 20_avg_episodic_return=1.0, curiosity_reward=27.136913299560547
# step=959858, 20_avg_episodic_return=1.0, curiosity_reward=27.93296241760254
# step=960412, 20_avg_episodic_return=1.0, curiosity_reward=25.730493545532227
# step=960851, 20_avg_episodic_return=1.0, curiosity_reward=26.10820960998535
# step=961214, 20_avg_episodic_return=1.0, curiosity_reward=27.687549591064453
# step=961632, 20_avg_episodic_return=1.0, curiosity_reward=27.009008407592773
# step=961943, 20_avg_episodic_return=1.0, curiosity_reward=27.98004150390625
# step=962316, 20_avg_episodic_return=1.0, curiosity_reward=26.82236671447754
# step=962782, 20_avg_episodic_return=1.0, curiosity_reward=26.527923583984375
# step=963316, 20_avg_episodic_return=1.0, curiosity_reward=26.311321258544922
# step=963647, 20_avg_episodic_return=1.0, curiosity_reward=27.91815757751465
# step=964014, 20_avg_episodic_return=1.0, curiosity_reward=27.946331024169922
# step=964413, 20_avg_episodic_return=1.0, curiosity_reward=27.738468170166016
# step=964770, 20_avg_episodic_return=1.0, curiosity_reward=27.05214500427246
# step=965395, 20_avg_episodic_return=1.0, curiosity_reward=25.340866088867188
# step=965741, 20_avg_episodic_return=1.0, curiosity_reward=27.76784896850586
# step=966189, 20_avg_episodic_return=1.0, curiosity_reward=26.948955535888672
# step=966505, 20_avg_episodic_return=1.0, curiosity_reward=29.343368530273438
# step=967216, 20_avg_episodic_return=1.0, curiosity_reward=25.45180320739746
# step=967563, 20_avg_episodic_return=1.0, curiosity_reward=27.10849952697754
# step=967993, 20_avg_episodic_return=1.0, curiosity_reward=27.004619598388672
# step=968386, 20_avg_episodic_return=1.0, curiosity_reward=26.526926040649414
# step=968748, 20_avg_episodic_return=1.0, curiosity_reward=27.414073944091797
# step=969063, 20_avg_episodic_return=1.0, curiosity_reward=28.129547119140625
# step=969733, 20_avg_episodic_return=1.0, curiosity_reward=25.98739242553711
# step=970182, 20_avg_episodic_return=1.0, curiosity_reward=27.227880477905273
# step=970547, 20_avg_episodic_return=1.0, curiosity_reward=27.774776458740234
# step=971018, 20_avg_episodic_return=1.0, curiosity_reward=25.86006736755371
# step=971424, 20_avg_episodic_return=1.0, curiosity_reward=26.814172744750977
# step=971888, 20_avg_episodic_return=1.0, curiosity_reward=26.750255584716797
# step=972280, 20_avg_episodic_return=1.0, curiosity_reward=26.477527618408203
# step=972657, 20_avg_episodic_return=1.0, curiosity_reward=27.773006439208984
# step=973156, 20_avg_episodic_return=1.0, curiosity_reward=25.588886260986328
# step=973572, 20_avg_episodic_return=1.0, curiosity_reward=27.631616592407227
# step=973955, 20_avg_episodic_return=1.0, curiosity_reward=27.08622169494629
# step=974327, 20_avg_episodic_return=1.0, curiosity_reward=27.735240936279297
# step=974792, 20_avg_episodic_return=1.0, curiosity_reward=26.201122283935547
# step=975345, 20_avg_episodic_return=1.0, curiosity_reward=25.37997055053711
# step=975824, 20_avg_episodic_return=1.0, curiosity_reward=27.258153915405273
# step=976216, 20_avg_episodic_return=1.0, curiosity_reward=27.189739227294922
# step=976515, 20_avg_episodic_return=1.0, curiosity_reward=29.066776275634766
# step=976889, 20_avg_episodic_return=1.0, curiosity_reward=27.564889907836914
# step=977335, 20_avg_episodic_return=1.0, curiosity_reward=27.5300350189209
# step=977853, 20_avg_episodic_return=1.0, curiosity_reward=26.330358505249023
# step=978405, 20_avg_episodic_return=1.0, curiosity_reward=27.964122772216797
# step=978851, 20_avg_episodic_return=1.0, curiosity_reward=27.451404571533203
# step=979238, 20_avg_episodic_return=1.0, curiosity_reward=27.589406967163086
# step=979547, 20_avg_episodic_return=1.0, curiosity_reward=28.132680892944336
# step=980062, 20_avg_episodic_return=1.0, curiosity_reward=27.928964614868164
# step=980502, 20_avg_episodic_return=1.0, curiosity_reward=27.078699111938477
# step=980900, 20_avg_episodic_return=1.0, curiosity_reward=26.669727325439453
# step=981349, 20_avg_episodic_return=1.0, curiosity_reward=26.535686492919922
# step=981620, 20_avg_episodic_return=1.0, curiosity_reward=30.257959365844727
# step=982073, 20_avg_episodic_return=1.0, curiosity_reward=26.47455406188965
# step=982559, 20_avg_episodic_return=1.0, curiosity_reward=26.311840057373047
# step=983080, 20_avg_episodic_return=1.0, curiosity_reward=26.101451873779297
# step=983420, 20_avg_episodic_return=1.0, curiosity_reward=28.036121368408203
# step=983950, 20_avg_episodic_return=1.0, curiosity_reward=25.475933074951172
# step=984352, 20_avg_episodic_return=1.0, curiosity_reward=28.78104591369629
# step=984632, 20_avg_episodic_return=1.0, curiosity_reward=28.57546615600586
# step=985037, 20_avg_episodic_return=1.0, curiosity_reward=26.807785034179688
# step=985525, 20_avg_episodic_return=1.0, curiosity_reward=26.912832260131836
# step=985982, 20_avg_episodic_return=1.0, curiosity_reward=28.209491729736328
# step=986406, 20_avg_episodic_return=1.0, curiosity_reward=26.743717193603516
# step=986749, 20_avg_episodic_return=1.0, curiosity_reward=28.656646728515625
# step=987180, 20_avg_episodic_return=1.0, curiosity_reward=26.78314208984375
# step=987480, 20_avg_episodic_return=1.0, curiosity_reward=27.70980453491211
# step=987953, 20_avg_episodic_return=1.0, curiosity_reward=26.448654174804688
# step=988350, 20_avg_episodic_return=1.0, curiosity_reward=27.300785064697266
# step=988867, 20_avg_episodic_return=1.0, curiosity_reward=26.851329803466797
# step=989138, 20_avg_episodic_return=1.0, curiosity_reward=27.941532135009766
# step=989645, 20_avg_episodic_return=1.0, curiosity_reward=26.336551666259766
# step=990153, 20_avg_episodic_return=1.0, curiosity_reward=26.471141815185547
# step=990617, 20_avg_episodic_return=1.0, curiosity_reward=27.01650619506836
# step=990982, 20_avg_episodic_return=1.0, curiosity_reward=27.084609985351562
# step=991324, 20_avg_episodic_return=1.0, curiosity_reward=27.566781997680664
# step=991815, 20_avg_episodic_return=1.0, curiosity_reward=26.31780433654785
# step=992230, 20_avg_episodic_return=1.0, curiosity_reward=27.344440460205078
# step=992517, 20_avg_episodic_return=1.0, curiosity_reward=28.066415786743164
# step=992961, 20_avg_episodic_return=1.0, curiosity_reward=26.357458114624023
# step=993315, 20_avg_episodic_return=1.0, curiosity_reward=27.989913940429688
# step=993706, 20_avg_episodic_return=1.0, curiosity_reward=27.91872215270996
# step=994164, 20_avg_episodic_return=1.0, curiosity_reward=26.588939666748047
# step=994628, 20_avg_episodic_return=1.0, curiosity_reward=26.45254898071289
# step=994976, 20_avg_episodic_return=1.0, curiosity_reward=27.5782527923584
# step=995480, 20_avg_episodic_return=1.0, curiosity_reward=26.015920639038086
# step=995847, 20_avg_episodic_return=1.0, curiosity_reward=28.063457489013672
# step=996240, 20_avg_episodic_return=1.0, curiosity_reward=27.313491821289062
# step=996587, 20_avg_episodic_return=1.0, curiosity_reward=27.588943481445312
# step=997052, 20_avg_episodic_return=1.0, curiosity_reward=26.573482513427734
# step=997509, 20_avg_episodic_return=1.0, curiosity_reward=27.084823608398438
# step=997900, 20_avg_episodic_return=1.0, curiosity_reward=27.0826473236084
# step=998227, 20_avg_episodic_return=1.0, curiosity_reward=27.99660873413086
# step=998803, 20_avg_episodic_return=1.0, curiosity_reward=25.71261978149414
# step=999253, 20_avg_episodic_return=1.0, curiosity_reward=26.735301971435547

# %% [markdown]
# ## Visualizing Curiosity Reward in PPO with RND
#
# In this section, we focus on analyzing the curiosity-driven exploration of the agent while solving an episode. The **curiosity reward**, a key component in the Random Network Distillation (RND) algorithm, measures how "novel" or "unpredictable" a state is to the agent. This intrinsic reward helps guide exploration in environments where external rewards are sparse or absent.
#
# ### Key Visualizations:
# 1. **Curiosity Reward vs. Steps**:
#    - The chart displays the trend of curiosity rewards across steps during an episode. It provides insights into how the agent encounters and evaluates novel states, highlighting periods of high novelty in model activity.
#
# 2. **High-Scoring States**:
#    - Below the plot, showcase images of the environmental states that resulted in the highest curiosity rewards. These snapshots offer a glimpse into the scenarios the agent found most novel or unpredictable, such as first appearance, revealing a new room, or having part of the view obstructed by a wall.

# %%
@torch.no_grad
def play(agent, args, rnd_model:RNDModel, obs_rms_mean, obs_rms_std):
    env = env_creator(args)
    env = VideoRecorder(env, ".")
    device = next(agent.parameters()).device
    obs, info = env.reset()

    frames_scores = []

    steps = 0
    reward = 0.0
    total_reward = 0.0

    while True:
        obs_norm = (
            (
                (torch.Tensor(obs).to(device) - torch.from_numpy(obs_rms_mean).to(device))
                / torch.sqrt(torch.from_numpy(obs_rms_std).to(device))
            ).clip(-5, 5)
        ).float()
        predict_next_feature, target_next_feature = rnd_model(obs_norm)
        steps_curiosity_rewards = ((target_next_feature - predict_next_feature).pow(2).sum(1) / 2).data
        frames_scores.append(steps_curiosity_rewards.item())

        action = agent.get_action_and_value(torch.Tensor(obs).unsqueeze(0).to(device))[0][0].item()
        obs, reward, terminated, truncated, info = env.step(action)

        steps += 1
        total_reward += reward

        if not (terminated or truncated):
            continue

        break
    print(f"reward: {reward}, steps: {steps}")
    env.close()
    return info, env._frames, frames_scores

_, frames, frames_scores = play(agent, args, rnd_model, trainer.obs_rms.mean, trainer.obs_rms.var)
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 430) to (608, 432) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# reward: 1.0, steps: 39

# %%
import heapq

unique_scores = list(set(frames_scores))
top_scores = heapq.nlargest(6, unique_scores)
intresting_frames_ixs = set()
for score in top_scores:
    indices_with_score = [ix for ix, val in enumerate(frames_scores) if val == score]
    intresting_frames_ixs.update(indices_with_score)
intresting_frames_ixs = list(intresting_frames_ixs)
intresting_frames_ixs.sort()

selected_frames = []
selected_scores = []
for ix in intresting_frames_ixs:
    selected_frames.append(frames[ix])
    selected_scores.append(frames_scores[ix])

images = selected_frames

descriptions = [
    f"Step: {fix}, Curiosity reward: {round(sc, 4)}" for (fix, sc) in zip(intresting_frames_ixs, selected_scores)
]

fig, axes = plt.subplots(2, 3, figsize=(20, 10))
axes = axes.flatten()
for ax, img, desc in zip(axes, images, descriptions):
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(desc, fontsize=10)

plt.tight_layout()
plt.show()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(list(range(len(frames_scores))), frames_scores, marker='o', linestyle='-', color='b', label='Frame Scores')
plt.title('Curiosity reward across episode completion')
plt.xlabel('Step')
plt.ylabel('Curiosity reward')
plt.grid(True)
plt.legend()
plt.show()

# %%
Video("trajectory.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
tlol.save_static_plots_in_notebook()
# Below charts that will be saved into notebook for solution evaluation
# IMPORTANT TIP - when training, there is a small chance that ppo will outperform ppo+rnd
